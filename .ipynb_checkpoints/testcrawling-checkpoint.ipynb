# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

url = "https://tumblbug.com/discover?ongoing=onGoing"

#html = urlopen("https://tumblbug.com/discover?ongoing=onGoing")
#bsObject = BeautifulSoup(html, "html.parser")


html = requests.get(url).text
#html
#print(bsObject)

# %%
#from selenium import webdriver
#import time

#chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
#driver = webdriver.Chrome(chromedriver)

#driver.get('https://tumblbug.com/discover?category=app&ongoing=onGoing')

#print("+" * 100)
#print(driver.title)
#print(driver.current_url)
#print("텀블벅 크롤링")
#print("-" * 100)

#a_tag = driver.find_elements_by_tag_name('a')
#href_text=a_tag.get_attribute('href')

#print(href_text)

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString

#url
#mainurl
#main_url = "https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt"
#suburl
sub_url = "https://tumblbug.com/snaptoonforwebtoon?ref=discover"

chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

#subpage
driver.get(sub_url)
sub_html = driver.page_source 

#mainpage
#driver.get(main_url)
#main_html = driver.page_source

sub_soup = BeautifulSoup(sub_html, 'html.parser')

projectName = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > h1')
brand = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > div > a')
category = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > a > span')
collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
remain_day = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(2) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA')
percentarchived = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(1) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA > span.ProjectIntroduction__FundingRate-sc-1o2ojgb-17.cNDicH')
goal = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.FundingInformation-cjd67l-0.gGtZns > div > span')

#sucessCriteria=100 fix (if site===tumblbug)
#site = tumblbug
#productOption = 
#productPrice = 

print("달성 금액: ")
for tag in collection(['span']):
    tag.replace_with('')
strcollection = collection.text.replace(",","")
print(strcollection)

print('\n'+"카테고리: ")
for i in category:
    nonsplitCategory = i.text.strip()
Category = nonsplitCategory.replace(" ","")
print('\n'+Category)

print('\n'+"프로젝트명 및 summary:")
for i in projectName: 
    ProjectName = i.text.strip()

ProjectName.replace(" ","")
print(ProjectName)

print('\n'+"브랜드:")
for i in brand: 
    Brand = i.text.strip()

print(Brand)

print('\n'+"남은 기간:")
for i in remain_day:
    day = i.text.strip()
daynum = len(day)
Daynum = day[:daynum-1]
print(Daynum)

print('\n'+"달성률:")
for i in percentarchived:
    pt = i.text.strip()
ptnum = len(pt)
Ptnum = pt[:ptnum-1]
print(Ptnum)

print('\n'+"목표 금액: ")
for i in goal:
    notsplit = i.text.strip()
split1 = notsplit.split("목표 금액인")
split2 = split1[1].split('원이')
goalmoney = split2[0].replace(",","").replace(" ","")
print(goalmoney)
# Out:
# 달성 금액:
# 42496000
#
# 카테고리:
#
# 만화·웹툰리소스
#
# 프로젝트명 및 summary:
# [스냅툰] 웹툰 배경 3종세트
#
# 브랜드:
# 엉클벅
#
# 남은 기간:
# 9시
#
# 달성률:
# 4249
#
# 목표 금액:
# 1000000

# %%
[object] <class 'bs4.element.NavigableString'> 
[repr]
24,504,000
-----
[object] <class 'bs4.element.Tag'>
[repr]
<span class="ProjectIntroduction__Small-sc-1o2ojgb-18 lnSbIU">원</span>
-----
[object] <class 'bs4.element.Tag'>
[repr]
<span class="ProjectIntroduction__FundingRate-sc-1o2ojgb-17 cNDicH">612<!-- -->%</span>
-----

열림~자식태그 닫기 = NavigableString
자식 = tag
자식~닫힌태그 = NavigableString
# Out:
#   File "<ipython-input-7-cdc9e81e870c>", line 1
#     [object] <class 'bs4.element.NavigableString'>
#               ^
# SyntaxError: invalid syntax

# %%
 --> 자식 태그 제거 방법 고민중..
#collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
#for bs_object in collection:
 #   print("[object]", type(bs_object))
  #  print("[repr]")
   # print(bs_object)
    #print("-----")
#collection = sub_soup.select_one("")
#target_tag = sub_soup.select_one("#target")
#target_text_without_child_tags = [
#    bs_object
#    for bs_object
#    in target_tag
#    if isinstance(bs_object, NavigableString)
#]
#text = "".join(target_text_wichout_child_tags)
#print(text)

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from selenium.webdriver.chrome.options import Options
import os
from urllib.request import urlopen
from lxml import etree
import pymysql
from datetime import datetime
import re


# mysql에 tumblbug crawling link 가져오기
class TumblbugCrawler:
    def __init__(self):
        self.conn = pymysql.connect(host='127.0.0.1', port=3307, user='root', password='Pami1227!*',
                               db='tumblbug_data', charset='utf8')

        #self.path = os.path.dirname(os.path.realpath('C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/'))

    def getUrlLister(self, page_url, nUrl):
        option = Options()

        option.add_argument("--disable-infobars")
        option.add_argument("start-maximized")
        option.add_argument("--disable-extensions")

        # Pass the argument 1 to allow and 2 to block
        option.add_experimental_option("prefs", {
        "profile.default_content_setting_values.notifications": 2
        })
        #driver = webdriver.Chrome(options=option, executable_path=self.path + "\chromedriver.exe")
        chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
        driver = webdriver.Chrome(chromedriver)

        driver.get(page_url)

        conn = self.conn
        curs = conn.cursor()

        SCROLL_PAUSE_TIME = 2
        # Get scroll height
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:

            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            #last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")


        for i in range(1, nUrl+1):
            xpath1 ='//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div['+str(i)+']/div/div/dl/dt/a'
            url = driver.find_element_by_xpath(xpath1)
            url = url.get_attribute('href')
            
            sql0 = "select * from tumblbug_urllist where url=\'%s\'" % (url)
            curs.execute(sql0)
            rows = curs.fetchall()
            status = 'F'
            if len(rows)==0:
                sql= "insert into tumblbug_urllist(url, crawled) values (\'%s\',\'%s\')"%(url,status)
                curs.execute(sql)
                conn.commit()

                print(i,url)
                
            
        conn.close()

        
    def tumblbugCrawler(self):
        con = self.conn
        curs = conn.cursor()
        
        sql = "select * from tumblbug_urllist where crawled='F' or crawled='DB insert error'"
        curs.execute(sql)
        rows = curs.fetchall()
        
        for row in rows:
            id = row[0]
            pagename = row[1]
            url = row[2]
            
            if url == 'None':
                continue;

            driver.get(url)
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            
            projectName = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > h1')
            brand = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > div > a')
            category = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > a > span')
            collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
            remain_day = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(2) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA')
            percentachieved = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(1) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA > span.ProjectIntroduction__FundingRate-sc-1o2ojgb-17.cNDicH')
            goal = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.FundingInformation-cjd67l-0.gGtZns > div > span')

            #category
            for i in category:
                Category = i.text.strip()
            
             #title
            for i in projectName: 
                title = i.text.strip()

            #brand
            for i in brand: 
                Brand = i.text.strip()
                
            #achieve
            for i in percentachieved:
                pt = i.text.strip()
            ptnum = len(pt)
            achieve = pt[:ptnum-1]

            #funding - 달성 금액
            for tag in collection(['span']):
                tag.replace_with('')
            Collection = collection.text.replace(",","")
          
            #supporter = NULL
            
            # likes = NULL
            
            # goal
            for i in goal:
                notsplit = i.text.strip()
            split1 = notsplit.split("목표 금액인")
            split2 = split1[1].split('원이')
            goalmoney = split2[0].replace(",","").replace(" ","")
            
            #remaining
            for i in remain_day:
                day = i.text.strip()
            daynum = len(day)
            remaining = day[:daynum-1]
       
            
"""
        n_scrollDown = nUrl//18+2
        k=0
        while k<n_scrollDown+1:
            k+=1
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if k == n_scrollDown:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            print(str(k)+"번 반복했습니다.")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
"""


if __name__ == '__main__':

    page_url = 'https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt'
    nUrl = 100
    wc = TumblbugCrawler()
    wc.getUrlLister(page_url, nUrl)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-0c26da15ddaf> in <module>
#     106     nUrl = 100
#     107     wc = TumblbugCrawler()
# --> 108     wc.getUrlLister(page_url, nUrl)
#
# <ipython-input-7-0c26da15ddaf> in getUrlLister(self, page_url, nUrl)
#      48             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      49             time.sleep(SCROLL_PAUSE_TIME)
# ---> 50             driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
#      51             time.sleep(SCROLL_PAUSE_TIME)
#      52             new_height = driver.execute_script("return document.body.scrollHeight")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=87.0.4280.88)

# %%
# !pip install pymysql

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from selenium.webdriver.chrome.options import Options
import os
from urllib.request import urlopen
from lxml import etree
import pymysql
from datetime import datetime
import re



class TumblbugCrawler:
    def __init__(self):
        self.conn = pymysql.connect(host='127.0.0.1', port=3307, user='root', password='Pami1227!*',
                               db='test', charset='utf8')

        #self.path = os.path.dirname(os.path.realpath(__file__))
        print('DB connected')

    def getUrlLister(self, page_url, nUrl):
        option = Options()

        option.add_argument("--disable-infobars")
        option.add_argument("start-maximized")
        option.add_argument("--disable-extensions")

        # Pass the argument 1 to allow and 2 to block
        option.add_experimental_option("prefs", {
        "profile.default_content_setting_values.notifications": 2
        })
        #driver = webdriver.Chrome(options=option, executable_path=self.path + "\chromedriver.exe")
        chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
        driver = webdriver.Chrome(chromedriver)
        SCROLL_PAUSE_TIME = 4

        driver.get(page_url)
        time.sleep(SCROLL_PAUSE_TIME)

        conn = self.conn
        curs = conn.cursor()


        # Get scroll height
#        last_height = driver.execute_script("return document.body.scrollHeight")
        last_height = 0
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            #print('down')
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
            #print('up')
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            #driver.execute_script("window.scrollTo(0, document.body.scrollHeight-300);")
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[1]/div/div/div[2]/a
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[1]/div/div/dl/dt/a

#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[2]/div/div/div[3]/a
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[2]/div/div/dl/dt/a

#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[3]/div/div/div[2]/a
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[3]/div/div/dl/dt/a


        for i in range(1, nUrl+1):
            xpath1 = '//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div['+str(i)+']/div/div/dl/dt/a'
            url = driver.find_element_by_xpath(xpath1)
            url = url.get_attribute('href')
            sql0 = "select * from tumblbug_urllist where url=\'%s\'" % (url)
            curs.execute(sql0)
            rows = curs.fetchall()
            status = 'F'
            if len(rows)==0:
                sql= "insert into tumblbug_urllist(url, crawled) values (\'%s\',\'%s\')"%(url,status)
                curs.execute(sql)
                conn.commit()

                print(i,url)
                    #url = url.get_attribute('href')
                    #print(url)
    #driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        conn.close()

"""
        n_scrollDown = nUrl//18+2
        k=0
        while k<n_scrollDown+1:
            k+=1
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if k == n_scrollDown:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            print(str(k)+"번 반복했습니다.")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
"""
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[1]/div/div/div[3]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[2]/div/div/div[2]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[3]/div/div/div[2]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[4]/div/div/div[3]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[5]/div/div/div[3]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[6]/div/div/div[2]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[7]/div/div/div[2]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[8]/div/div/div[2]/a/img
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[18]/div/div/dl/dt/a
#//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div[19]/div/div/dl/dt/a


if __name__ == '__main__':

    page_url = 'https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt'
    nUrl = 100
    wc = TumblbugCrawler()
    wc.getUrlLister(page_url, nUrl)
# Out:
# DB connected
# 1 https://tumblbug.com/snaptoonforwebtoon?ref=discover
# 2 https://tumblbug.com/everydaytoast?ref=discover
# 3 https://tumblbug.com/box_in_box?ref=discover
# 4 https://tumblbug.com/lavariete?ref=discover
# 5 https://tumblbug.com/booktravel?ref=discover
# 6 https://tumblbug.com/frk04?ref=discover
# 7 https://tumblbug.com/laches?ref=discover
# 8 https://tumblbug.com/leejunhyung?ref=discover
# 9 https://tumblbug.com/soumall?ref=discover
# 10 https://tumblbug.com/mansaok3651?ref=discover
# 11 https://tumblbug.com/iamamodel?ref=discover
# 12 https://tumblbug.com/010681?ref=discover
# 13 https://tumblbug.com/1203coffee?ref=discover
# 14 https://tumblbug.com/joaspot?ref=discover
# 15 https://tumblbug.com/jlccironmancard?ref=discover
# 16 https://tumblbug.com/2021tae05?ref=discover
# 17 https://tumblbug.com/mfj33?ref=discover
# 18 https://tumblbug.com/monosandalos?ref=discover
# 19 https://tumblbug.com/deep_one?ref=discover
# 20 https://tumblbug.com/storingmonths?ref=discover
# 21 https://tumblbug.com/tikkle?ref=discover
# 22 https://tumblbug.com/thesecondprojectofsaan?ref=discover
# 23 https://tumblbug.com/socialplantsclub3?ref=discover
# 24 https://tumblbug.com/mannylonq?ref=discover
# 25 https://tumblbug.com/ppablowave?ref=discover
# 26 https://tumblbug.com/365mansa?ref=discover
# 27 https://tumblbug.com/handlog?ref=discover
# 28 https://tumblbug.com/musical_mendella_?ref=discover
# 29 https://tumblbug.com/fromkimsan?ref=discover
# 30 https://tumblbug.com/go01?ref=discover
# 31 https://tumblbug.com/2020oil?ref=discover
# 32 https://tumblbug.com/woodcalender?ref=discover
# 33 https://tumblbug.com/twosquares?ref=discover
# 34 https://tumblbug.com/harubread?ref=discover
# 35 https://tumblbug.com/seeds?ref=discover
# 36 https://tumblbug.com/sarm2?ref=discover
# 37 https://tumblbug.com/monthlydeviationvol14?ref=discover
# 38 https://tumblbug.com/zerokong?ref=discover
# 39 https://tumblbug.com/sobal2021?ref=discover
# 40 https://tumblbug.com/dotdesign2?ref=discover
