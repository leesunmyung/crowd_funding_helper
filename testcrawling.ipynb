# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

url = "https://tumblbug.com/discover?ongoing=onGoing"

#html = urlopen("https://tumblbug.com/discover?ongoing=onGoing")
#bsObject = BeautifulSoup(html, "html.parser")


html = requests.get(url).text
#html
#print(bsObject)

# %%
#from selenium import webdriver
#import time

#chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
#driver = webdriver.Chrome(chromedriver)

#driver.get('https://tumblbug.com/discover?category=app&ongoing=onGoing')

#print("+" * 100)
#print(driver.title)
#print(driver.current_url)
#print("텀블벅 크롤링")
#print("-" * 100)

#a_tag = driver.find_elements_by_tag_name('a')
#href_text=a_tag.get_attribute('href')

#print(href_text)

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString

#url
#mainurl
#main_url = "https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt"
#suburl
sub_url = "https://tumblbug.com/snaptoonforwebtoon?ref=discover"

chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

#subpage
driver.get(sub_url)
sub_html = driver.page_source 

#mainpage
#driver.get(main_url)
#main_html = driver.page_source

sub_soup = BeautifulSoup(sub_html, 'html.parser')

projectName = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > h1')
brand = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > div > a')
category = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > a > span')
collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
remain_day = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(2) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA')
percentarchived = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(1) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA > span.ProjectIntroduction__FundingRate-sc-1o2ojgb-17.cNDicH')
goal = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.FundingInformation-cjd67l-0.gGtZns > div > span')

#sucessCriteria=100 fix (if site===tumblbug)
#site = tumblbug
#productOption = 
#productPrice = 

print("달성 금액: ")
for tag in collection(['span']):
    tag.replace_with('')
strcollection = collection.text.replace(",","")
print(strcollection)

print('\n'+"카테고리: ")
for i in category:
    nonsplitCategory = i.text.strip()
Category = nonsplitCategory.replace(" ","")
print('\n'+Category)

print('\n'+"프로젝트명 및 summary:")
for i in projectName: 
    ProjectName = i.text.strip()

ProjectName.replace(" ","")
print(ProjectName)

print('\n'+"브랜드:")
for i in brand: 
    Brand = i.text.strip()

print(Brand)

print('\n'+"남은 기간:")
for i in remain_day:
    day = i.text.strip()
daynum = len(day)
Daynum = day[:daynum-1]
print(Daynum)

print('\n'+"달성률:")
for i in percentarchived:
    pt = i.text.strip()
ptnum = len(pt)
Ptnum = pt[:ptnum-1]
print(Ptnum)

print('\n'+"목표 금액: ")
for i in goal:
    notsplit = i.text.strip()
split1 = notsplit.split("목표 금액인")
split2 = split1[1].split('원이')
goalmoney = split2[0].replace(",","").replace(" ","")
print(goalmoney)
# Out:
# 달성 금액:
# 42496000
#
# 카테고리:
#
# 만화·웹툰리소스
#
# 프로젝트명 및 summary:
# [스냅툰] 웹툰 배경 3종세트
#
# 브랜드:
# 엉클벅
#
# 남은 기간:
# 9시
#
# 달성률:
# 4249
#
# 목표 금액:
# 1000000

# %%
[object] <class 'bs4.element.NavigableString'> 
[repr]
24,504,000
-----
[object] <class 'bs4.element.Tag'>
[repr]
<span class="ProjectIntroduction__Small-sc-1o2ojgb-18 lnSbIU">원</span>
-----
[object] <class 'bs4.element.Tag'>
[repr]
<span class="ProjectIntroduction__FundingRate-sc-1o2ojgb-17 cNDicH">612<!-- -->%</span>
-----

열림~자식태그 닫기 = NavigableString
자식 = tag
자식~닫힌태그 = NavigableString
# Out:
#   File "<ipython-input-7-cdc9e81e870c>", line 1
#     [object] <class 'bs4.element.NavigableString'>
#               ^
# SyntaxError: invalid syntax

# %%
 --> 자식 태그 제거 방법 고민중..
#collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
#for bs_object in collection:
 #   print("[object]", type(bs_object))
  #  print("[repr]")
   # print(bs_object)
    #print("-----")
#collection = sub_soup.select_one("")
#target_tag = sub_soup.select_one("#target")
#target_text_without_child_tags = [
#    bs_object
#    for bs_object
#    in target_tag
#    if isinstance(bs_object, NavigableString)
#]
#text = "".join(target_text_wichout_child_tags)
#print(text)

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from selenium.webdriver.chrome.options import Options
import os
from urllib.request import urlopen
from lxml import etree
import pymysql
from datetime import datetime
import re


# mysql에 tumblbug crawling link 가져오기
class TumblbugCrawler:
    def __init__(self):
        self.conn = pymysql.connect(host='127.0.0.1', port=3307, user='root', password='Pami1227!*',
                               db='tumblbug_data', charset='utf8')

        #self.path = os.path.dirname(os.path.realpath('C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/'))

    def getUrlLister(self, page_url, nUrl):
        option = Options()

        option.add_argument("--disable-infobars")
        option.add_argument("start-maximized")
        option.add_argument("--disable-extensions")

        # Pass the argument 1 to allow and 2 to block
        option.add_experimental_option("prefs", {
        "profile.default_content_setting_values.notifications": 2
        })
        #driver = webdriver.Chrome(options=option, executable_path=self.path + "\chromedriver.exe")
        chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
        driver = webdriver.Chrome(chromedriver)

        driver.get(page_url)

        conn = self.conn
        curs = conn.cursor()

        SCROLL_PAUSE_TIME = 2
        # Get scroll height
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:

            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            #last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")


        for i in range(1, nUrl+1):
            xpath1 ='//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div['+str(i)+']/div/div/dl/dt/a'
            url = driver.find_element_by_xpath(xpath1)
            url = url.get_attribute('href')
            
            sql0 = "select * from tumblbug_urllist where url=\'%s\'" % (url)
            curs.execute(sql0)
            rows = curs.fetchall()
            status = 'F'
            if len(rows)==0:
                sql= "insert into tumblbug_urllist(url, crawled) values (\'%s\',\'%s\')"%(url,status)
                curs.execute(sql)
                conn.commit()

                print(i,url)
                
            
        conn.close()

        
    def tumblbugCrawler(self):
        con = self.conn
        curs = conn.cursor()
        
        sql = "select * from tumblbug_urllist where crawled='F' or crawled='DB insert error'"
        curs.execute(sql)
        rows = curs.fetchall()
        
        for row in rows:
            id = row[0]
            pagename = row[1]
            url = row[2]
            
            if url == 'None':
                continue;

            driver.get(url)
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            
            projectName = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > h1')
            brand = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > div > a')
            category = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > a > span')
            collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
            remain_day = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(2) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA')
            percentachieved = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(1) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA > span.ProjectIntroduction__FundingRate-sc-1o2ojgb-17.cNDicH')
            goal = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.FundingInformation-cjd67l-0.gGtZns > div > span')
            

            #category
            for i in category:
                Category = i.text.strip()
            Category = nonsplitCategory.replace(" ","")
             #title
            for i in projectName: 
                title = i.text.strip()

            #brand
            for i in brand: 
                Brand = i.text.strip()
                
            #achieve
            for i in percentachieved:
                pt = i.text.strip()
            ptnum = len(pt)
            achieve = pt[:ptnum-1]

            #funding - 달성 금액
            for tag in collection(['span']):
                tag.replace_with('')
            Collection = collection.text.replace(",","")
          
            #supporter = NULL
            
            # likes = NULL
            
            # goal
            for i in goal:
                notsplit = i.text.strip()
            split1 = notsplit.split("목표 금액인")
            split2 = split1[1].split('원이')
            goalmoney = split2[0].replace(",","").replace(" ","")
            
            #remaining
            for i in remain_day:
                day = i.text.strip()
            daynum = len(day)
            remaining = day[:daynum-1]
       
            
"""
        n_scrollDown = nUrl//18+2
        k=0
        while k<n_scrollDown+1:
            k+=1
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if k == n_scrollDown:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            print(str(k)+"번 반복했습니다.")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
"""


if __name__ == '__main__':

    page_url = 'https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt'
    nUrl = 100
    wc = TumblbugCrawler()
    wc.getUrlLister(page_url, nUrl)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-0c26da15ddaf> in <module>
#     106     nUrl = 100
#     107     wc = TumblbugCrawler()
# --> 108     wc.getUrlLister(page_url, nUrl)
#
# <ipython-input-7-0c26da15ddaf> in getUrlLister(self, page_url, nUrl)
#      48             driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      49             time.sleep(SCROLL_PAUSE_TIME)
# ---> 50             driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
#      51             time.sleep(SCROLL_PAUSE_TIME)
#      52             new_height = driver.execute_script("return document.body.scrollHeight")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=87.0.4280.88)

# %%
# !pip install pymysql

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from selenium.webdriver.chrome.options import Options
import os
from urllib.request import urlopen
from lxml import etree
import pymysql
from datetime import datetime
import re



class TumblbugCrawler:
    def __init__(self):
        self.conn = pymysql.connect(host='127.0.0.1', port=3307, user='root', password='Pami1227!*',
                               db='test', charset='utf8')

        #self.path = os.path.dirname(os.path.realpath(__file__))
        print('DB connected')

    def getUrlLister(self, page_url, nUrl):
        option = Options()

        option.add_argument("--disable-infobars")
        option.add_argument("start-maximized")
        option.add_argument("--disable-extensions")

        # Pass the argument 1 to allow and 2 to block
        option.add_experimental_option("prefs", {
        "profile.default_content_setting_values.notifications": 2
        })
        #driver = webdriver.Chrome(options=option, executable_path=self.path + "\chromedriver.exe")
        chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
        driver = webdriver.Chrome(chromedriver)
        SCROLL_PAUSE_TIME = 4

        driver.get(page_url)
        time.sleep(SCROLL_PAUSE_TIME)

        conn = self.conn
        curs = conn.cursor()


        # Get scroll height
#        last_height = driver.execute_script("return document.body.scrollHeight")
        last_height = 0
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            #print('down')
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-1000);")
            #print('up')
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            
        for i in range(1, nUrl+1):
            xpath1 = '//*[@id="react-view"]/div[3]/div[1]/div[2]/div/div[2]/div['+str(i)+']/div/div/dl/dt/a'
            url = driver.find_element_by_xpath(xpath1)
            #url = url.get_attribute('href')
            sql0 = "select * from tumblbug_urllist where url=\'%s\'" % (url)
            curs.execute(sql0)
            rows = curs.fetchall()
            status = 'F'
            if len(rows)==0:
                sql= "insert into tumblbug_urllist(url, crawled) values (\'%s\',\'%s\')"%(url,status)
                curs.execute(sql)
                conn.commit()

                print(i,url)
                    #url = url.get_attribute('href')
                    #print(url)
    #driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        #conn.close()
    def tumblbugCrawler(self):
        conn = self.conn
        curs = conn.cursor()
        
        sql = "select * from tumblbug_urllist where crawled='F' or crawled='DB insert error'"
        curs.execute(sql)
        rows = curs.fetchall()
        
        chromedriver = 'C:/Users/ljy01/Desktop/chromedriver/chromedriver_win32/chromedriver.exe'
        driver = webdriver.Chrome(chromedriver)
        
        for row in rows:
            id = row[0]
            pagename = "tumblbug"#row[2]
            url = row[1]
            
            if url == 'None':
                continue;

            driver.get(url)
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            sub_html = driver.page_source 

            sub_soup = BeautifulSoup(sub_html, 'html.parser')
            
            projectName = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > h1')
            brand = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > div > a')
            Category = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > div.ProjectIntroduction__ProjectOutline-sc-1o2ojgb-2.jbdzfG > div > a > span')
            collection = sub_soup.find('div',attrs={'class': 'ProjectIntroduction__StatusValue-sc-1o2ojgb-16 lgJcVA'})
            remain_day = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(2) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA')
            percentachieved = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.ProjectIntroduction__FundingStatus-sc-1o2ojgb-13.jqTlEc > div:nth-child(1) > div.ProjectIntroduction__StatusValue-sc-1o2ojgb-16.lgJcVA > span.ProjectIntroduction__FundingRate-sc-1o2ojgb-17.cNDicH')
            goal = sub_soup.select('#react-view > div.ProjectIntroduction__ProjectIntroductionBackground-sc-1o2ojgb-0.gsZkXT > div > div > aside > div.FundingInformation-cjd67l-0.gGtZns > div > span')
            pagename = "tumblbug"
        
            print("success1\n")
            #category        
            for i in Category:
                category = i.text.strip()
            category = category.replace(" ","")
            
            #title
            for i in projectName: 
                title = i.text.strip()

            #brand
            for i in brand: 
                Brand = i.text.strip()
                
            #achieve
            for i in percentachieved:
                pt = i.text.strip()
            ptnum = len(pt)
            achieve = pt[:ptnum-1]

            #funding - 달성 금액
            for tag in collection(['span']):
                tag.replace_with('')
            funding = collection.text.replace(",","")
          
            supporter = "tobe"
            
            # likes = NULL
            
            # goal
            for i in goal:
                notsplit = i.text.strip()
            split1 = notsplit.split("목표 금액인")
            split2 = split1[1].split('원이')
            goalmoney = split2[0].replace(",","").replace(" ","")
            
            #remaining
            for i in remain_day:
                day = i.text.strip()
            daynum = len(day)
            remaining = day[:daynum-1]
        
            #endate - 수작업
            endate = "tobe"
            print("success2\n")
        
            sql1 = 'insert into tumblbug_crawl (id, pagename, category, title, achieve, funding, supporter, goal,remaining, endate)\
                                                    value(%d,\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\')'\
                                                        %(id, pagename, category, title, achieve, funding, supporter, goal, remaining, endate)
            curs.execute(sql1)
            conn.commit()
            print("success3\n")
            print('Crawling '+url+' finish',sql1)

            conn.commit()
            sql_url = "update tumblbug_urllist set status='펀딩중', crawled='T' where url=\'%s\'"% (url)  #where id -> where url
            curs.execute(sql_url)
            conn.commit()
        conn.close()
       
"""
        n_scrollDown = nUrl//18+2
        k=0
        while k<n_scrollDown+1:
            k+=1
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if k == n_scrollDown:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            print(str(k)+"번 반복했습니다.")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight-100);")
"""

if __name__ == '__main__':

    page_url = 'https://tumblbug.com/discover?ongoing=onGoing&sort=endedAt'
    nUrl = 100
    wc = TumblbugCrawler()
    wc.getUrlLister(page_url, nUrl)
    wc.tumblbugCrawler()
# Out:
# DB connected
# 1 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="7f1a6aa6-7e49-4e49-815d-9ee34c4dfc6f")>
# 2 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="04565178-16e5-4ed3-9d7c-9a2a17d86b81")>
# 3 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="1d1a30be-f173-4e0f-8df9-8d8e0f28b818")>
# 4 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="f8f9ef7f-2b2c-4534-837a-4edb292886b5")>
# 5 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="23cfd87d-cb6e-4581-b45a-64f95ab0f920")>
# 6 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="325163e9-79a4-491c-97e9-d9aef4cce0a2")>
# 7 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="4a2b9b1f-9c8b-46e4-9b75-2edcf0d86c5b")>
# 8 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="43bb6c05-1660-4f6e-86c5-4748b670981e")>
# 9 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="c4cee242-3967-4b25-883a-619fbd2a452f")>
# 10 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="5a34ed16-fca6-445d-aa4a-6a40669a0c7d")>
# 11 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="3cdd2058-116f-411b-adac-51cf10415e91")>
# 12 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="1fc506b3-b2d2-4cc4-9cfd-1e7d2cb56c94")>
# 13 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="50cd97a5-e39c-47cd-a196-f6322abc7692")>
# 14 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="3a126bd4-9c82-4527-a3bd-95f6bc77186f")>
# 15 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="b1bc9ebe-af48-47b9-8276-2f874bec52d5")>
# 16 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="6e8d686c-05c4-4256-9dbf-7eb8b7c7095f")>
# 17 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="27c82e06-b009-481f-bf06-8afec869d9d5")>
# 18 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="7a15a7bd-83ce-4608-99dd-9cd25a9b35d9")>
# 19 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="3550c8a7-81c3-4638-ba9a-c28fa870edb0")>
# 20 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="8e176323-7b4a-41fa-9cc0-475bff461122")>
# 21 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="bb2771db-a79c-49ef-ba55-5b083c5fde65")>
# 22 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d0616a3e-2d64-4fe1-aee6-38dcdba87b37")>
# 23 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="67d01935-785c-4e1f-84dd-053303ef7d44")>
# 24 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="4549dd58-1a04-4f91-9162-cbd08207bcb3")>
# 25 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="30b436f2-f63c-4346-9b1b-70ebf92e8abf")>
# 26 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="aa4859d5-aa0d-42e0-9788-e1c998ee4752")>
# 27 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="b82570c0-6539-4e7f-bbc6-8f0c00f2821f")>
# 28 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="2340c0a9-313d-4b3c-bbd4-5b6848ddb6f8")>
# 29 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="ed535480-7b8a-40cf-8759-8b5abee55e90")>
# 30 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d920c1a4-cf92-4e77-98e3-b1df9d748c00")>
# 31 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="5112b495-ba82-4668-bf50-0e54d619acec")>
# 32 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="691ab2d3-defb-452a-af62-0f6a8f5a804f")>
# 33 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="9cf1a71f-68fa-4857-a493-54fbcd0df16e")>
# 34 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="dc6c5b33-7cbd-4760-8a38-9558ee560e4e")>
# 35 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="c4284975-3faf-477d-b566-35682b66e9b1")>
# 36 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="be61906f-0a52-428b-bb4f-bd50297a4059")>
# 37 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="2cd77d0d-d01a-43ab-b604-5e5058792952")>
# 38 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="91447819-2164-456a-b6d3-9260d6b8e838")>
# 39 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="b222af25-3488-4fdb-94e0-dfb85eaf4fa2")>
# 40 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="92217871-4751-42cc-b864-fdc01401b8fb")>
# 41 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="53ff627e-ae95-4bd7-b9d9-499bc7496375")>
# 42 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="b7235699-cec9-43dd-a2b1-4e57aa882183")>
# 43 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="c18797c3-994a-4ab6-b933-9d9ad0bb247c")>
# 44 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="32797867-970d-4740-a890-9bb21cd65817")>
# 45 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="13eb709d-a5cf-46c6-b0fc-6f2a51aa0022")>
# 46 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="1dcd4131-bc71-4933-8100-02c764e06efe")>
# 47 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="10ea4c28-fdec-42f9-aaab-a8cba2d487b7")>
# 48 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d296e1b2-0065-4187-bd41-34311a663987")>
# 49 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d500ec58-8331-4b36-8304-e050b20df234")>
# 50 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="695ecb70-5c84-409f-a9fa-fbd8c33e0cc9")>
# 51 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d5ee52ec-0e26-4f22-b4f3-f6861fe7ef3d")>
# 52 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="54191039-2560-4fd6-af22-ff16cb097d76")>
# 53 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="25d37e35-1fb3-48c2-8c0d-1db76b99895e")>
# 54 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="17e1a2cc-8b99-4785-8d19-9ae4a33ebdf9")>
# 55 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="e5becccc-a024-4d18-aee9-2c8cc9c850c0")>
# 56 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="42f20b78-3ae7-4bc1-97fd-6e3b8dd34a10")>
# 57 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="2ae41f69-2826-4f50-af51-f5f4a7363a4e")>
# 58 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="2fc53d9a-c014-4cc9-8fff-129bc4648ba2")>
# 59 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="ef8479ed-3f7a-49db-b538-6eaae753e758")>
# 60 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="fd197872-c72a-4d59-ae77-d5db4ceee63c")>
# 61 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="0d8a66be-3083-4453-b19b-84b4226e919b")>
# 62 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="752cb6bb-cf19-425f-98ee-c0f29b472508")>
# 63 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="e1db6ff9-b6e2-482b-83c1-0b0835e81848")>
# 64 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="15333fb9-02ed-4f25-9dfe-10977a465e4c")>
# 65 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="9cb283ad-f561-4b99-8bfd-0edb9cb9cdfa")>
# 66 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="86b8f971-115c-4216-8f2f-47092b7ca0c2")>
# 67 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="52658be3-4864-4d15-9888-a2c7355f914d")>
# 68 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="44801a9b-064a-46c9-97d8-631ed3bc668c")>
# 69 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="a53dee0e-e30a-4f0b-8e0a-270bd9da07ba")>
# 70 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="cecac8c5-9a40-4a2b-a2d4-5636be0028ec")>
# 71 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="0ded3d54-ea2f-4ea3-8199-3ada415d01a2")>
# 72 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="a0f8bad7-07d0-4e24-be41-58a93495569f")>
# 73 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="3e8815ba-cc62-4f20-9cf3-f5388fa36079")>
# 74 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="7af169c6-9080-464f-88f3-713f11cb9d91")>
# 75 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="038b17c1-c73d-4be2-93be-0aeb53a62668")>
# 76 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="8f52f4d7-331b-4a2e-86e9-7dce607d6bb9")>
# 77 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="ca038434-9830-41cf-9750-604c871cd814")>
# 78 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="70105853-229f-4691-9494-66e3b87d420b")>
# 79 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="a7e04562-cb81-45ad-914c-816c9feed155")>
# 80 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="07e416a5-29df-4ad6-9284-d4a1f442790c")>
# 81 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="fdaf8d22-76b9-4f2b-b2f3-cc7fe1fd21c7")>
# 82 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="0e7d048b-b59f-4c24-a25f-c85b360c3118")>
# 83 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="91c85f42-8976-43d5-a696-e38abad4744d")>
# 84 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="57d516e6-0bd4-480a-beee-7dab72c11053")>
# 85 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d6bcb53e-22fa-4747-903e-83f1eacfbd54")>
# 86 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="fb62ada5-dab4-4de8-bc0d-5b06f492ceaa")>
# 87 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="7c23a694-289e-4695-985d-950208cd75a9")>
# 88 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="629b4e01-8e36-4c5f-98ba-2e5facabdd07")>
# 89 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="37069f92-a4b2-4659-96d8-6735dd0fc2e2")>
# 90 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="65d25190-9f10-47a7-94fe-fdb514b24a76")>
# 91 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="ec2dec86-b3d4-426a-8d69-5d3714720ebc")>
# 92 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="ff97cb7f-f511-41d5-8609-38f35917d083")>
# 93 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="c8dc33e1-64b5-4016-b0ba-62949eae720e")>
# 94 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="b48a8790-8b93-4ea2-b1fa-2d92938b22ae")>
# 95 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="06169e35-6eca-4c79-adce-716a736acb9b")>
# 96 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="53c92c17-317b-4f6b-b780-3b93759004dc")>
# 97 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="d719384c-d783-4c72-bd4b-2a4273f62de7")>
# 98 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="66e761c1-48dc-454c-a225-b12b9ab5d8f3")>
# 99 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="445ee57f-8324-4fc4-8a5f-54750f6f7ddc")>
# 100 <selenium.webdriver.remote.webelement.WebElement (session="af41f029b39a48c0c8d90004172b8de9", element="35353382-0f1d-47c2-be43-1f9da465c7b2")>
# success1
#
# success2
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-54-423fbbdb2608> in <module>
#     207     wc = TumblbugCrawler()
#     208     wc.getUrlLister(page_url, nUrl)
# --> 209     wc.tumblbugCrawler()
#
# <ipython-input-54-423fbbdb2608> in tumblbugCrawler(self)
#     163                                                     value(%d,\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\',\'%s\')'\
#     164                                                         %(id, pagename, category, title, achieve, funding, supporter, goal, remaining, endate)
# --> 165             curs.execute(sql1)
#     166             conn.commit()
#     167             print("success3\n")
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     503                 sql = sql.encode(self.encoding, 'surrogateescape')
#     504         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 505         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     506         return self._affected_rows
#     507
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     722         else:
#     723             result = MySQLResult(self)
# --> 724             result.read()
#     725         self._result = result
#     726         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1067     def read(self):
#    1068         try:
# -> 1069             first_packet = self.connection._read_packet()
#    1070
#    1071             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     674             if self._result is not None and self._result.unbuffered_active is True:
#     675                 self._result.unbuffered_active = False
# --> 676             packet.raise_for_error()
#     677         return packet
#     678
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     221         errno = self.read_uint16()
#     222         if DEBUG: print("errno =", errno)
# --> 223         err.raise_mysql_exception(self._data)
#     224
#     225     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     105     if errorclass is None:
#     106         errorclass = InternalError if errno < 1000 else OperationalError
# --> 107     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '김산' 시티팝 EP앨범 <From. Kimsan>','117','5894000','tobe','[<span>목표' at line 1")
