# %%
import pymysql

# %%
conn = pymysql.connect(host='127.0.0.1', user='root', password='wdta2181',db='test', charset='utf8')

curs = conn.cursor()

sql = "select id ,title from test.crawl"
curs.execute(sql)
rows = curs.fetchall()

for row in rows :
    row = list(row)
rows = list(rows)
print(rows)
print(type(rows))

for row in rows :
    #print(row[1])
    if row[1][-1]  == ' ' :
        row[1] = row[1].rstrip()
        print(row[1])
conn.close()
# Out:
# [(1, '10억 펀딩 신소재 베타젤 다리베개로 다리 붓기다리 케어 다리힐링'), (2, '아름다운 나만의 수족관을 만들어 보세요! 아쿠아 가든'), (3, '입고있는 팬티 싹 바꿨어요. Y존 건강 8천원대 Y NOT 드로즈'), (4, '글로벌 1억펀딩 뻐근한 내 몸 근적외선 빛으로 전신 찜질!'), (5, '이제 회사에서도 주말에도 함께 할 감성 데일리백 투웨이 버킷백'), (6, '식약처기능성확인탈모샴푸 대한민국 샴푸의 기준이 되겠습니다 클라우드랩'), (7, '건강한피부를 위한 최고의 선물 거품의 차이를 느껴보세요UNI프리미엄솝'), (8, '4억앵콜10만원 중반 국민코트 진화된 구스 캐시미어 핸드메이드 코트'), (9, ' 4.9점 앵콜 식감깡패 빠삭바삭 앵커버터+구운현미 프랑스누룽지'), (10, '가방에쏙~휴대용보관파우치로언제어디서나! 핸디전기매트'), (11, '앵콜 펀딩 믿고 먹는 오땡 양고기 '), (12, '앵콜만족도 5점만점 4kg대 오토폴딩 유모차 헤라시스'), (13, '아침에는 역시 사과! 건강한 아침의 시작 미미청 사과쥬스'), (14, '오가다 100 호박즙껍질부터 씨앗까지 다 넣어 진하게 마셔봐!'), (15, '앵콜!! 캐시미어울나일론 올인원! 돌아온 황금비율 아이코닉 니트!'), (16, '연기멍 들어보셨나요?연기까지 디자인한 인센스버너 힐링을 챙기세요'), (17, '샴푸 하나로 개털의 기준을 바꾸~개! 유해성 논란성분 20가지 무!'), (18, '잡생각이 많은 당신에게 드리는 취미처방 한지플라워DIY키트!'), (19, '댕냥환장템 아마 산책말고 집에서 놀자할걸요? 교감놀이 장난감~'), (20, '레알 찐맛탱 피넛버터와 코코넛이 프레첼에? 단짠꼬의 혁명! '), (21, '루시르히트 발열에 IOT 기능까지?? 기본에 충실한 신박한 패딩조끼 '), (22, '앵콜 아날로그적인 감성과 유니크함을 넣으세요.바르데로 더 케이스'), (23, '글로벌 7억+앵콜 스키와 스케이트의 만남! 신개념 윈터스포츠 스노우핏'), (24, '6만원대 소가죽부담없이 누리자! 착화감 좋은 세븐홀 화이트 스니커즈'), (25, '인센스스틱홀더향기를 담는 케이스 _ 바르데로 더케이스2'), (26, '모발 튼튼~~ 두피 튼튼~~ 헤어 엔 Hair G~~'), (27, '앵콜 유분모공관리? 피노누아 버블로 모공 속 노폐물까지 관리하세요'), (28, '마스크 스트랩 알러지 걱정없이 평생 쓰는 써
? 강력한 크런치튀김과 닭다리살의 완벽조화더빠삭치킨'), (63, '홈트의 화룡점정 내 방을 헬스장으로 만드는10만원대의 로프 트레이너'), (64, '삼겹살 1근을 10분만에 알아서 구워주는 베스타노 IH 인덕션 오븐'), (65, '고양이를 위한 냥신과 히끄의 자연친화적 고양이모래 노블샌드23'), (66, '글로벌11억펀딩MOFT 노트북태블릿 파우치와 거치대를 하나로!'), (67, '4.6평점 1만원대 기모슬랙스 앵콜바지 전문공장이 자신있게 선보입니다.'), (68, '임상 5가지눈가주름 팔자주름 목주름 I 멜팅 주름밤으로 밀착해결'), (69, '5211 평점 4.6 앵콜 상체가 조각상이 될텐데 괜찮으시겠어요?'), (70, '5634 앵콜 가격은 서브 스펙은 메인듀얼 드라이버 무선이어폰'), (71, '무선다리미 혁신 셔츠다림질에 까다로운 영국신사들이 열광한 모피리처드!'), (72, '앵콜 1시간 먹는 껌 킹콩스틱 with 씨벅톤 정글브로 소우신간식'), (73, 'Ostay air Dock for dyson '), (74, '전세계 300개 한정프랑스 메이드 오토매틱 명품 워치 르네 모리스'), (75, '휴대용 프린터기 어디까지 써보셨어요? 누구나 쉽게 상상을 현실로P1'), (76, '업템포X바디프로필 2021년 인생몸매 주인공을 찾습니다 I 퓨어워터'), (77, '1.5억펀딩리얼? 1mm 핑거그립 무선충전차량거치스탠드 모두가능'), (78, '단 1원으로 필터교체를? 무한필터 자동세척 가습공기청정기 스워셔'), (79, '앵콜 스포츠의 한계를 넘어서는 가능성'), (80, '팬톤컬러 루미르스마트조명 I 조명만 바꿨는데 인테리어가 완성됐다'), (81, '카드와 지폐 모두 깔끔하게 수납가능한 UX 카드지갑'), (82, '힐리언스 선마을 대표 셰프의 프리미엄 파김치! 맛과 건강을 사로잡다!'), (83, '20년 원단 장인의 진짜 명품핏 팬츠 2만원대 테이퍼드 슬랙스'), (84, '모모스틱 슬림그립케이스무선충전핑거그립거치기능은 물론 삼성페이까지!'), (85, '유산균도 박사가 만들면 다르다 1일 1포하는 당근 포스트바이오틱스!'), (86, '1.3억 앵콜 하루만에 수분140증가! 임상후기검증 갈바닉 마스크'), (87, '불과 전기가 없어도 라면을 만들어먹다? 등산여행차박에 !마법의 바로쿡'), (88, '2억앵콜 2만원대 소가죽 크로스백홀리데이 스페셜로 돌아오다!'), (89, '역대급 만족도 남성필수템! 미친 퀄리티의 프리미엄 면도크림'), (90, '5만원대로 팬톤무선이어폰+듀얼충전패드? 그런데 그것이 실제 일어났습니다!'), (91, '2만원대 살균기 언택트 시대 지친 마음 달래는 똑똑한 살균 에티켓'), (92, '1차 607  ...
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-33136539ae79> in <module>
#      16     #print(row[1])
#      17     if row[1][-1]  == ' ' :
# ---> 18         row[1] = row[1].rstrip()
#      19         print(row[1])
#      20 conn.close()
#
# TypeError: 'tuple' object does not support item assignment
