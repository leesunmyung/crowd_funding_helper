# %%
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
from future.utils import iteritems
from collections import Counter
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pymysql

# %%
article_data = pd.read_csv('mixver8.txt', encoding='utf-8', header= None)
documents = [' '.join(i[0].split(' ')[1:]) for i in article_data.values]

# %%
#print(documents[0])

# %%
as_one = ''
for document in documents:
    as_one = as_one + ' ' + document
words = as_one.split()

# %%
words[0:10]
# Out:
# ['캔', '용기', '친환경', '제품', '활용', '쌀국수', '쌀', '생각', '영어', '강아지']

# %%
counts = Counter(words)

# %%
vocab = sorted(counts, key=counts.get, reverse=True)

# %%
word2idx = {word.encode("utf8").decode("utf8"): ii for ii, word in enumerate(vocab,1)}

# %%
idx2word = {ii: word for ii, word in enumerate(vocab)}

# %%
V = len(word2idx)
N = len(documents)

# %%
tf = CountVectorizer()

# %%
tf.fit_transform(documents)
# Out:
# <1x8549 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8549 stored elements in Compressed Sparse Row format>

# %%
tf.fit_transform(documents)[0:1].toarray()
# Out:
# array([[ 30, 315,  10, ...,   5,  10,  15]], dtype=int64)

# %%
tfidf = TfidfVectorizer(max_features = 1000, max_df=1, min_df=0)

#generate tf-idf term-document matrix
A_tfidf_sp = tfidf.fit_transform(documents)  #size D x V

# %%
tfidf_dict = tfidf.get_feature_names()
print(tfidf_dict)
# Out:
# ['가격', '가구', '가득', '가루', '가방', '가슴', '가요', '가위', '가을', '가이드', '가이드북', '가장', '가족', '가죽', '가지', '가치', '각인', '간식', '간편', '간호', '갈비', '감각', '감귤', '감동', '감성', '감정', '강사', '강아지', '개념', '개발', '개선', '거리', '거울', '거치', '거품', '걱정', '건강', '건조', '건축', '걸이', '검증', '게임', '겨울', '겨울나기', '결혼', '경량', '경력', '경험', '계란', '계절', '고급', '고기', '고래', '고민', '고양이', '골드', '공간', '공감', '공개', '공기', '공룡', '공부', '공식', '공연', '공용', '공존', '관리', '광고', '괴물', '교육', '교체', '구독', '구두', '구름', '구리', '구성', '구스', '국내', '국민', '국산', '귀걸이', '규어', '그녀', '그대', '그린', '그림', '그림책', '기념', '기능', '기록', '기름', '기모', '기본', '기부', '기분', '기술', '기억', '기적', '기준', '기타', '기획', '김치', '깔창', '꿀잠', '나노', '나무', '나이트', '남녀', '남성', '남자', '낭만', '내내', '냄새', '네이버웹툰', '노래', '노트', '노트북', '노하우', '놀이', '높이', '누리', '느낌', '니트', '다른', '다리', '다운', '다이아', '다이아몬드', '다이어리', '다이어트', '다크', '닥터', '단독', '단백질', '단편', '단편영화', '단행본', '달달', '달력', '달빛', '달콤', '담요', '대로', '대신', '대표', '대학', '대학교', '대학생', '대한', '대한민국', '대형', '대화', '덕후', '데님', '데스크', '데이', '도구', '도마', '도시', '도예', '도자기', '도전', '독도', '독립', '독일', '동네', '동물', '동시', '동양', '동화', '두번째', '두유', '두피', '드라마', '드로잉', '드로즈', '등장', '디자이너', '디자인', '디저트', '디지털', '떡볶이', '라면', '라이트', '라이프', '러닝', '러브', '럭셔리', '런칭', '레깅스', '레더', '레드', '레시피', '레이', '레이스', '레이어', '레트로', '로맨스', '로우', '로컬', '로퍼', '리다', '리드', '리버시', '리스', '리얼', '리텍', '마법', '마사지', '마스크', '마약', '마우스', '마을', '마음', '마이', '마케팅', '만난', '만남', '만능', '만들기', '만족', '만족도', '만화', '만화책', '맛집', '맞춤', '매듭', '매력', '매출', '매트', '매트리스', '머그컵', '머리', '머신', '머플러', '먼지', '멀티', '메리', '메리노', '메모', '메이드', '메이커', '메이크업', '면역', '멸종위기', '명작', '명품', '모공', '모니터', '모던', '모든', '모바일', '모습', '모양', '모음', '모이', '모자', '모집', '모찌', '목걸이', '목도리', '무게', '무대', '무드', '무드등', '무릎', '무선', '무스', '무엇', '문구', '문제', '문학', '문화', '물결', '뮤지컬', '미국', '미니', '미니백', '미백', '미생물', '미술', '미스트', '민화', '밀크', '바다', '바디', '바람', '바이오', '바지', '박스', '반려', '반려견', '반려동물', '반지', '반짝', '받침', '발견', '발라', '발매', '발열', '발효', '밤하늘', '방법', '방석', '방수', '방식', '방지', '방향', '배경', '배송', '백팩', '백화점', '밴드', '밸런스', '뱃지', '뱅쇼', '버려진', '버블', '버전', '버킷', '버터', '버핏', '벌꿀', '베개', '베다', '베리', '베스트', '베이스', '베타', '벨벳', '벨트', '변신', '변화', '별자리', '보고', '보관', '보드', '보드게임', '보따리', '보석', '보습', '보온', '보이', '보증', '보호', '복숭아', '본격', '부담', '부부', '부산', '부자', '부츠', '분리', '분석', '분위기', '브라', '브라운', '브랜드', '브러쉬', '브루', '브릭', '블랙', '블럭', '블록', '블루', '비건', '비누', '비밀', '비법', '비타민', '비트', '빈티', '뿌리', '사계절', '사과', '사람', '사랑', '사용', '사이', '사이즈', '사이클링', '사전', '사진', '삭스', '산책', '살균', '상상', '상점', '새해', '색감', '샌드', '생각', '생명', '생산', '생존', '생활', '샤워', '샤인', '샴푸', '서비스', '서울', '서포터', '선물', '선인장', '설치', '설탕', '섬유', '성공', '성분', '성장', '세계', '세상', '세척', '세탁', '세트', '센스', '셀프', '셋업', '셔츠', '셰프', '소개', '소금', '소녀', '소리', '소설', '소스', '소원', '소장', '소재', '소파', '소품', '소프트', '손목', '솔루션', '수건', '수납', '수면', '수분', '수제', '수채화', '수트', '숙면', '순간', '순이', '숨기', '스니커즈', '스마트', '스마트폰', '스카프', '스케치업', '스크래쳐', '스키', '스타', '스타일', '스탠드', '스텀', '스테이크', '스토리', '스톤', '스튜디오', '스트랩', '스트레스', '스티커', '스틱', '스파', '스페셜', '스펙', '스포츠', '스푼', '스피커', '슬랙스', '슬림', '슬링', '습관', '시간', '시계', '시대', '시리즈', '시인', '시작', '시즌', '시집', '시트', '식단', '식물', '식초', '식탁', '신고', '신발', '신소재', '신화', '실내', '실리콘', '실무', '실버', '실용', '실전', '실천', '실크', '실화', '심리', '심플', '싱글', '쓰레기', '아기', '아동', '아빠', '아웃도어', '아이', '아이템', '아이패드', '아침', '아크릴', '아트', '아티스트', '아파트', '안감', '안경', '안내서', '안대', '안심', '안전', '알파카', '앞치마', '애니메이션', '애플', '액세서리', '액션', '액자', '앨범', '앰플', '양말', '양면', '양식', '어깨', '어른', '어린이', '어서', '언택트', '얼굴', '엄마', '업무', '에너지', '에디', '에세이', '에센스', '에어', '에어팟', '에코', '에코백', '엑스트라', '여름', '여성', '여유', '여자', '여정', '여행', '여행지', '역사', '연구', '연극', '연기', '연말', '연어', '연주', '연출', '엽서', '영국', '영상', '영양', '영어', '영화', '영화제', '예방', '예술', '예술가', '오디오', '오르다', '오리', '오버', '오브', '오일', '오픈', '온기', '온라인', '올인원', '올해', '옷장', '와디', '완성', '왕실', '외출', '요가', '요리', '용기', '용량', '용품', '우드', '우산', '우울', '우주', '운동', '운영', '움직', '워치', '워커', '워터', '원단', '원료', '원목', '원피스', '월간', '웨어', '웨이', '웹툰', '위드', '위로', '위생', '위해', '유기견', '유기농', '유기동물', '유니크', '유럽', '유리', '유모차', '유산균', '유지', '음반', '음식', '음식물', '음악', '응원', '의류', '이기', '이니셜', ' ...

# %%
import sys
if sys.version_info <= (2,7):
    reload(sys)
    sys.setdefaultencoding('utf-8')
import konlpy
from konlpy.tag import Kkma, Okt, Hannanum

kkma = Kkma()
okt = Okt()
hannanum = Hannanum()
print('konlpy version = %s' % konlpy.__version__)
# Out:
# konlpy version = 0.5.2

# %% [markdown]
# ## 하늘마당

# %%
sent='''
당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타
강화도 청소년들이 전하는 섬의 이야기가 담긴 고구마를 요리로 즐겨보세요!
고급향수야? 룸스프레이야? 전세계 고급호텔 향 3만원대 한병에 담다!
7일 한정크리스마스 할머니의 산나물을 담은 오감만족 크리스마스 만찬
집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리
모공 연구 10년 흡수 노하우 스위스 검증 비타민C 화장품
7일 단골특집 펀딩요청쇄도! 모공쫙~맑고 탱탱한 피부변화오메가믹스
완판신화 돌아왔다! 김은 먹고 다니냐? 명품 해남 곱창김 100
단 한 권에 열 권을 담은 당신을 위한 디지털 다이어리 SOK
뻔한 음식 말고 간편한 장어로! 세상 맛있는 꿀장어 홈키트
누적 구매평 7천건 찐리뷰가 인정하는 찐 춘천 닭갈비를 간편하게!
200개 한정 제주 매거진 인iiin과 제주 로컬푸드 정기배송!
와인전문가가 추천하는 셰프소믈리에 캐링백+와인잔 컬렉션
입 냄새나 숨 쉬지마! 이제 모과글로 숨 크게 쉬자!
업그레이드 앵콜 다시한번 가격파괴 차량용 무선충전 거치대 핸디그랩
즐거운 요리의 시작 상하좌우 내부까지 ALL 티타늄 도마
45년 전통 3대째 내려오는 비법 된장콩잎
글로벌 26억펀딩 1만원대 6in1만능케이블 inCharge6'''
#print('꼬꼬마 명사: ', kkma.nouns(sent))
print(okt.nouns(sent))
#print('한나눔 명사: ', hannanum.nouns(sent))
# Out:
# ['당장', '밥말', '파스타', '데이', '루나', '바지락', '국물', '파스타', '강화도', '청소년', '전하', '섬', '이야기', '고구마', '요리', '고급', '향수', '룸', '스프레이', '전세계', '고급', '호텔', '향', '병', '한정', '크리스마스', '할머니', '산나물', '오감', '만족', '크리스마스', '만찬', '집콕', '필수', '템', '설탕', '물엿', '상큼', '감귤', '프리바이오틱', '비타민', '젤리', '모공', '연구', '흡수', '노하우', '스위스', '검증', '비타민', '화장품', '단골', '특집', '펀딩', '요청', '쇄도', '쫙', '피부', '변화', '메가믹스', '완판', '신화', '김', '명품', '해남', '곱창', '김', '단', '권', '열', '권', '당신', '위', '디지털', '다이어리', '음식', '장어', '세상', '꿀', '장어', '홈', '키트', '누적', '구매', '평', '리뷰', '인정', '춘천', '닭갈비', '개', '한정', '제주', '인', '과', '제주', '로컬', '푸드', '정기', '배송', '와인', '전문가', '추천', '셰프', '소믈리에', '캐링', '와인잔', '컬렉션', '입', '냄새', '숨', '이제', '모과', '글', '숨', '크게', '업그레이드', '앵콜', '다시', '한번', '가격파괴', '차량', '용', '무선', '충전', '거치', '핸', '디그', '랩', '요리', '시작', '상하좌우', '내부', '티타늄', '도마', '전통', '비법', '된장', '콩잎', '글로벌']

# %%
noun_set = set(okt.nouns(sent))
selected_word = []


for i in noun_set:
    if i in tfidf_dict:
        selected_word.append(i)
        continue
selected_word   
from gensim.models import word2vec

model = word2vec.Word2Vec.load("NaverMovie29.model")
for i in selected_word:
    print(i)
    print(model.wv.most_similar(positive=[i],topn=7))
    print()
type(model.wv.most_similar(positive=[i],topn=7))
# Out:
# 파스타
# [('바지락', 0.7601950764656067), ('루나', 0.6870887279510498), ('국물', 0.686908483505249), ('라자냐', 0.6833146214485168), ('데이', 0.6010187268257141), ('대장', 0.5666640996932983), ('쉐프', 0.5652799010276794)]
#
# 청소년
# [('성교육', 0.6625813245773315), ('강화도', 0.5792220234870911), ('복합', 0.5605188608169556), ('섬', 0.5465184450149536), ('국제', 0.5450730323791504), ('아티', 0.5410159826278687), ('옥상달빛', 0.5315104126930237)]
#
# 인정
# [('드라이버', 0.6227047443389893), ('서브', 0.6172699332237244), ('메인', 0.6116296648979187), ('듀얼', 0.5494078397750854), ('스펙', 0.50569748878479), ('애플', 0.49579471349716187), ('아마존', 0.49148184061050415)]
#
# 티타늄
# [('베르투', 0.6989498734474182), ('필드', 0.6928489208221436), ('콜', 0.6498568058013916), ('워치', 0.5904011130332947), ('치', 0.5544862747192383), ('이미드', 0.5465946197509766), ('안경', 0.5436388850212097)]
#
# 신화
# [('그리스', 0.6007416248321533), ('처마', 0.5149204730987549), ('완판', 0.5066978931427002), ('밑', 0.48438572883605957), ('스텐팬', 0.4826985001564026), ('요괴', 0.4784921705722809), ('글리터', 0.4690580368041992)]
#
# 셰프
# [('힐리', 0.7358962893486023), ('파김치', 0.7228657007217407), ('언스', 0.691354513168335), ('순삭', 0.5835816860198975), ('소믈리에', 0.5550969243049622), ('컷팅', 0.5540109872817993), ('대표', 0.5493565797805786)]
#
# 명품
# [('근본', 0.5613387823104858), ('브랜드', 0.5606425404548645), ('테이', 0.553491473197937), ('퍼드', 0.5450671911239624), ('수페르가', 0.5272097587585449), ('오토', 0.525395929813385), ('원사', 0.5200299620628357)]
#
# 세상
# [('뿐', 0.4828765392303467), ('군밤', 0.3815227150917053), ('수가', 0.3765507936477661), ('영문', 0.36194276809692383), ('로서', 0.35072627663612366), ('조끼', 0.3495597243309021), ('양고기', 0.3493478298187256)]
#
# 데이
# [('파스타', 0.6010187268257141), ('루나', 0.5527563095092773), ('바지락', 0.5517724752426147), ('국물', 0.533672571182251), ('미니미니', 0.46228256821632385), ('귤', 0.45020461082458496), ('데이트', 0.4467192590236664)]
#
# 연구
# [('튀김', 0.6477522253990173), ('프로바이오틱스', 0.5870808362960815), ('살의', 0.5672491788864136), ('닭다리', 0.5483181476593018), ('크런치', 0.5217980146408081), ('완벽', 0.5108500123023987), ('근육', 0.5038560628890991)]
#
# 정기
# [('구독', 0.8146662712097168), ('패닉', 0.7358187437057495), ('아홉', 0.6233260631561279), ('퍼포밍', 0.5966829061508179), ('서비스', 0.5904523134231567), ('버튼', 0.5781288146972656), ('하노', 0.5712152719497681)]
#
# 충전
# [('무선', 0.6886420249938965), ('시어스', 0.6562795639038086), ('충전기', 0.6423523426055908), ('뱅크', 0.6364589929580688), ('헬', 0.6094702482223511), ('급속', 0.5873017311096191), ('진공청소기', 0.559343159198761)]
#
# 무선
# [('충전기', 0.7115084528923035), ('뱅크', 0.696570634841919), ('듀얼', 0.6936521530151367), ('충전', 0.6886420249938965), ('진공청소기', 0.6853797435760498), ('드라이버', 0.6550338268280029), ('고속', 0.6310434341430664)]
#
# 컬렉션
# [('농부', 0.514891505241394), ('감칠맛', 0.4875834584236145), ('애니메이션', 0.47966426610946655), ('직송', 0.44363167881965637), ('임명', 0.43185892701148987), ('경력', 0.4303187429904938), ('정산', 0.4284029006958008)]
#
# 검증
# [('갈바', 0.6899949312210083), ('백신', 0.643378496170044), ('어쩌', 0.6053363084793091), ('증가', 0.5715378522872925), ('후기', 0.5673830509185791), ('임', 0.5392485857009888), ('폭주', 0.5266851186752319)]
#
# 변화
# [('해삼', 0.5380876660346985), ('교사', 0.4773460924625397), ('팬데믹', 0.47683727741241455), ('토트', 0.45878490805625916), ('앰플', 0.4553726315498352), ('쏙쏙', 0.4549379348754883), ('미래', 0.4539647698402405)]
#
# 비법
# [('임원경제지', 0.5562440156936646), ('남현', 0.5438516736030579), ('뽀개기', 0.5284081697463989), ('카라멜', 0.507552981376648), ('유자', 0.48508620262145996), ('백과사전', 0.47540581226348877), ('투잡', 0.47497299313545227)]
#
# 고급
# [('식기', 0.5788415670394897), ('원목', 0.48202264308929443), ('식탁', 0.4458691477775574), ('키핑', 0.4329076409339905), ('호텔', 0.4303414523601532), ('구멍', 0.42817389965057373), ('진', 0.4263056516647339)]
#
# 크리스마스
# [('랩그', 0.5229108333587646), ('기념일', 0.5026077032089233), ('배송', 0.4992416799068451), ('슬로', 0.49840131402015686), ('회식', 0.48593348264694214), ('캐롤', 0.48334771394729614), ('고생', 0.48121869564056396)]
#
# 차량
# [('보냉컵홀더', 0.7072256803512573), ('방향', 0.6875123977661133), ('트라이던트', 0.6718697547912598), ('와이퍼', 0.663313627243042), ('발상', 0.6592909693717957), ('모빌리티', 0.6268508434295654), ('고속', 0.6165198087692261)]
#
# 필수
# [('템', 0.7317408323287964), ('유튜', 0.5481163263320923), ('목줄', 0.5305280685424805), ('작업시간', 0.509685754776001), ('내열', 0.507609486579895), ('퇴각', 0.499018132686615), ('워킹', 0.4959718585014343)]
#
# 감귤
# [('더덕', 0.7565351128578186), ('쑥', 0.7152763605117798), ('가루차', 0.6996951699256897), ('가루', 0.6852022409439087), ('달콤', 0.6557760238647461), ('생강', 0.6002892255783081), ('첨가', 0.5634647607803345)]
#
# 할머니
# [('손녀', 0.6252766847610474), ('선생님', 0.5299394130706787), ('하라', 0.4958895444869995), ('지옥', 0.46446719765663147), ('그때', 0.4630149006843567), ('스승', 0.4595443606376648), ('긴급', 0.45831298828125)]
#
# 로컬
# [('전라도', 0.7443259954452515), ('청년', 0.5851726531982422), ('냉동', 0.5582941770553589), ('농부', 0.5576599836349487), ('도시락', 0.5534493327140808), ('카이', 0.5418550968170166), ('샐러드', 0.5352309942245483)]
#
# 호텔
# [('숙박', 0.6825549602508545), ('느와르', 0.6330935955047607), ('거리', 0.5466867089271545), ('복합', 0.5362339615821838), ('세렌', 0.5275828838348389), ('홈파티', 0.5258605480194092), ('실내', 0.5213697552680969)]
#
# 다이어리
# [('애뽈', 0.547089159488678), ('캡처', 0.5289818048477173), ('파크', 0.526792049407959), ('만년', 0.5182099342346191), ('여섯', 0.4996572732925415), ('러브스토리', 0.49485665559768677), ('물고기', 0.48241910338401794)]
#
# 만족
# [('숨숨', 0.6522876024246216), ('충분', 0.6330910325050354), ('타워', 0.6134055852890015), ('트윈', 0.5807024240493774), ('평균', 0.5218461751937866), ('안성맞춤', 0.5003505945205688), ('코너', 0.5003153085708618)]
#
# 키트
# [('밀', 0.49808651208877563), ('처방', 0.4846890866756439), ('채식', 0.474406898021698), ('잡', 0.46512776613235474), ('검사', 0.4409739673137665), ('수질검사', 0.43728503584861755), ('포포', 0.4324086308479309)]
#
# 이야기
# [('관', 0.5111422538757324), ('요괴', 0.5054046511650085), ('일간', 0.4885374903678894), ('뱅글', 0.4694766402244568), ('헌법', 0.4668000638484955), ('물음', 0.46095484495162964), ('최후', 0.45735323429107666)]
#
# 향수
# [('압생트', 0.6381242871284485), ('향기', 0.5969595909118652), ('르파써', 0.5894495248794556), ('퍼퓸', 0.5784803032875061), ('바닐라', 0.576743483543396), ('리운스', 0.573127031326294), ('무화과', 0.57077956199646)]
#
# 요리
# [('동결', 0.5467566847801208), ('레테', 0.5465644598007202), ('수가', 0.5238927602767944), ('바지락', 0.5093973875045776), ('강화도', 0.5037859082221985), ('요빠', 0.5029476284980774), ('루스', 0.47274619340896606)]
#
# 배송
# [('러프', 0.6388880014419556), ('랩그', 0.621864914894104), ('고생', 0.5615411996841431), ('프로포즈', 0.5517458915710449), ('신선', 0.5468385219573975), ('기념일', 0.5032730102539062), ('크리스마스', 0.4992416799068451)]
#
# 모공
# [('사수', 0.7332134246826172), ('피지', 0.6384673118591309), ('노폐물', 0.6284451484680176), ('각질', 0.604012668132782), ('미생물', 0.6011121273040771), ('클렌', 0.5870965719223022), ('럼', 0.581421434879303)]
#
# 전통
# [('소반', 0.5197558999061584), ('낙', 0.5114439129829407), ('현대', 0.5110406279563904), ('멋', 0.5040949583053589), ('호담', 0.4939139485359192), ('참기름', 0.4925781488418579), ('냉면', 0.4703485369682312)]
#
# 전세계
# [('오토', 0.6437082290649414), ('독자', 0.6423739790916443), ('돈버는법', 0.6373146772384644), ('총', 0.5790894031524658), ('유튜브', 0.5651547908782959), ('무려', 0.5513654947280884), ('매틱', 0.5360123515129089)]
#
# 집콕
# [('직소', 0.5864244699478149), ('문화생활', 0.5816187858581543), ('해금', 0.5771797895431519), ('색동', 0.5520679354667664), ('악기', 0.5515193343162537), ('샷', 0.5478984117507935), ('호스', 0.5453653335571289)]
#
# 비타민
# [('항산화', 0.6697179675102234), ('사표', 0.6601564884185791), ('잔틴', 0.6498023271560669), ('프로폴리스', 0.6494013071060181), ('히알루론산', 0.6374908685684204), ('유효', 0.6291641592979431), ('노폐물', 0.6265820264816284)]
#
# 전문가
# [('한국인', 0.5233403444290161), ('자주', 0.5129767060279846), ('왕초보', 0.5069162845611572), ('특허성', 0.49736058712005615), ('자시', 0.4819865822792053), ('러그', 0.4723542034626007), ('고소', 0.45111989974975586)]
#
# 화장품
# [('체험판', 0.7688106894493103), ('나노입자', 0.7489228248596191), ('엑소', 0.7446900606155396), ('포렌', 0.6399761438369751), ('도화지', 0.6164268255233765), ('미백', 0.6134697198867798), ('비결', 0.6093385815620422)]
#
# 냄새
# [('알콜', 0.5899933576583862), ('마밍스', 0.5814982652664185), ('분비물', 0.5784974098205566), ('리운스', 0.5744802355766296), ('헤파', 0.5516417026519775), ('퍼프', 0.5497885346412659), ('관능', 0.5478374361991882)]
#
# 디지털
# [('캡처', 0.5918022394180298), ('아날로그', 0.5741104483604431), ('퍼팅', 0.5642138123512268), ('연습기', 0.5499052405357361), ('급상승', 0.5359973311424255), ('봇', 0.4932844042778015), ('페이스북', 0.4849500358104706)]
#
# 시작
# [('금물', 0.4869341254234314), ('핵심', 0.47860339283943176), ('기구', 0.4678218364715576), ('자리', 0.45282894372940063), ('체지방', 0.4488215446472168), ('사과쥬스', 0.44115686416625977), ('나인', 0.437116414308548)]
#
# 추천
# [('홈트족', 0.6221533417701721), ('카밋', 0.6033972501754761), ('신용', 0.5917493104934692), ('체크카드', 0.5755856037139893), ('설계서', 0.5685237646102905), ('인문학', 0.5243115425109863), ('증명', 0.5123111605644226)]
#
# 젤리
# [('첨가', 0.6322730183601379), ('프리바이오틱스', 0.6316365003585815), ('비타', 0.5531480312347412), ('면역', 0.5368430614471436), ('설탕', 0.5251771211624146), ('약사', 0.5045793056488037), ('엘라스', 0.5019527673721313)]
#
# 설탕
# [('슈카', 0.7893131971359253), ('대체', 0.7883390188217163), ('탄산음료', 0.7450883388519287), ('상큼', 0.579170823097229), ('청포도', 0.568420946598053), ('젤리', 0.5251772403717041), ('홍차', 0.5126670598983765)]
#
# 도마
# [('숨결', 0.6608103513717651), ('원목', 0.6254805326461792), ('데코', 0.585180401802063), ('달인', 0.5518218278884888), ('민국', 0.49952441453933716), ('베젤', 0.4989272654056549), ('플레이', 0.4957282543182373)]
#
# 피부
# [('도화지', 0.6675198078155518), ('가려움', 0.6373969316482544), ('앰플', 0.6073091626167297), ('진정', 0.60366290807724), ('알란', 0.6013978719711304), ('민감', 0.601391077041626), ('토시', 0.5995503664016724)]
#
# 음식
# [('장어', 0.5666564702987671), ('한식', 0.5578290224075317), ('임원경제지', 0.5551370978355408), ('번은', 0.5300190448760986), ('안주', 0.5128332376480103), ('두부', 0.5070459842681885), ('분식', 0.5029366612434387)]
#
# 제주
# [('풋귤', 0.6276240348815918), ('한라산', 0.5738049745559692), ('벡', 0.5298047065734863), ('귤', 0.5197679996490479), ('슬로우', 0.5118120908737183), ('황금향', 0.509245753288269), ('유리컵', 0.48210394382476807)]
#
# 거치
# [('충전기', 0.7089862823486328), ('태블릿', 0.6435789465904236), ('드라이기', 0.6166495084762573), ('스마트폰', 0.6147574782371521), ('모빌리티', 0.6093692779541016), ('뱅크', 0.5842967629432678), ('휴대폰', 0.5794508457183838)]
#
# 노하우
# [('미드', 0.6009979844093323), ('실전', 0.5777756571769714), ('베이비', 0.5565658807754517), ('쇼핑몰', 0.5175293684005737), ('꿀팁', 0.5170364379882812), ('수익', 0.5168361663818359), ('상세', 0.5142558813095093)]
# list

# %%
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password='0000',db='test', charset='utf8')

curs = conn.cursor()


#print('꼬꼬마 명사: ', kkma.nouns(sent))
#print(okt.nouns(sent))
#print('한나눔 명사: ', hannanum.nouns(sent))
username="하늘마당"
sql = "select distinct I.title from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username
sql1 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '%s' and C.title = I.title;"%username

curs.execute(sql)
sent = curs.fetchall()


curs.execute(sql1)
title_with_category = curs.fetchall()
print("=======title with category=========")
#print(title_with_category)
print("=======title with category=========")

noun_set = set(okt.nouns(str(sent)))
selected_word = []

#selected_word : tokenized word from user's funding title list
for i in noun_set:
    if i in tfidf_dict:
        selected_word.append(i)
        continue
final_word_list = []
category_list=[]
print("=======category list=======")
for i in selected_word:
    sql3 = "select distinct I.title, C.category from test.user_info I, test.crawl C where username like '{username}' and C.title = I.title and I.title like '%%{word}%%';".format(username=username, word=i);
    curs.execute(sql3)
    rows = curs.fetchall()
    #print(rows)
    
    for j in rows:
        if i in j[0]:
            final_word_list.append(i)
            category_list.append(j[1])
            #print(i, j[1])
print("=======category list=======")  
from gensim.models import word2vec

model = word2vec.Word2Vec.load("NaverMovie29.model")
word_len = len(final_word_list)
category_len = len(category_list)
count=0
for i in range(word_len):
    print(final_word_list[i], category_list[i])
    print()
    similar_word=model.wv.most_similar(positive=[final_word_list[i]],topn=7)
    for j in similar_word:
        if len(j[0])==1:
            continue
        else:
            print(j[0])
            sql = "select DISTINCT pagename, category, title from test.crawl where title like '%%%s%%'" %j[0]
            curs.execute(sql)
            words = curs.fetchall()
            conn.commit()
            #print(words)
            length = len(words)
            if length>3:
                length = 3
            #print(length)
            for k in range(0,length):
                if words[k][1] == category_list[i]:
                    print(words[k])
                    count=count+1

                    
    print()

print(count)
conn.close()
# Out:
# =======title with category=========
# =======title with category=========
# =======category list=======
# =======category list=======
# 파스타 푸드
#
# 바지락
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 루나
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# 국물
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '추운겨울에 생각나는 따듯한 국물 올바른다시팩으로 더 진하고 건강하게!')
# 라자냐
# ('wadiz', '푸드', '육즙 팡~ 한우가 씹히는! 진한 라구소스 볼로네제 라자냐 파스타')
# ('wadiz', '푸드', '라자냐도 고기없이 가능하다구요? SNS에서 난리난 채식라자냐')
# ('wadiz', '푸드', '지중해의 맛 다른 라자냐와 견줄 수 없어요! 가지 라자냐 파스타 밀키트')
# 데이
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# 대장
# ('wadiz', '푸드', '꼬숩 달달 할매 손맛 3대장! 흑임자쑥곡물 컬러밀 라떼가 왔어요~')
# ('wadiz', '푸드', '인생떡볶이소스클래스가 다른 떡볶이 끝판 대장들만 모았다!')
# 쉐프
# ('wadiz', '푸드', '나는 오늘 쉐프가 된다 부채살 스테이크')
# ('wadiz', '푸드', '맛간장과 스페셜키트가 주는 쉐프의 품격 따또ttatto')
#
# 청소년 푸드
#
# 성교육
# 강화도
# ('wadiz', '푸드', '강화도 청소년들이 전하는 섬의 이야기가 담긴 고구마를 요리로 즐겨보세요!')
# 복합
# 국제
# 아티
# ('tumblbug', '푸드', '새로운 아티장 치즈와 샤퀴테리로 돌아온 치즈플로')
# 옥상달빛
#
# 인정 푸드
#
# 드라이버
# 서브
# 메인
# 듀얼
# 스펙
# 애플
# ('wadiz', '푸드', '파지사과로 만든 자연발효 까미노 양구 애플 사이더 비니거')
# ('wadiz', '푸드', '무슨 술이 이렇게 맛있어? 홈술필수템 블루베리 애플사이더 와쥬블루')
# 아마존
#
# 티타늄 홈리빙
#
# 베르투
# 필드
# 워치
# 이미드
# 안경
#
# 신화 푸드
#
# 그리스
# 처마
# 완판
# ('wadiz', '푸드', '완판신화 돌아왔다! 김은 먹고 다니냐? 명품 해남 곱창김 100')
# 스텐팬
# 요괴
# 글리터
#
# 셰프 홈리빙
#
# 힐리
# 파김치
# 언스
# 순삭
# 소믈리에
# ('wadiz', '홈리빙', '와인전문가가 추천하는 셰프소믈리에 캐링백+와인잔 컬렉션')
# 컷팅
# ('wadiz', '홈리빙', '닿는순간 순삭컷팅 스위스 셰프들이 극찬한 순삭 칼! 젠코')
# 대표
#
# 명품 푸드
#
# 근본
# 브랜드
# 테이
# ('wadiz', '푸드', '특별한 새해 5만원에 즐기는 백화점 1++ 한우 등심채끝 스테이크!')
# 퍼드
# 수페르가
# 오토
# 원사
#
# 세상 푸드
#
# 군밤
# ('wadiz', '푸드', '신개념 군밤 알아서 툭! 까지는 세상 간편한 맛있는 군밤용 칼집밤')
# 수가
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 영문
# 로서
# 조끼
# 양고기
# ('wadiz', '푸드', '앵콜 펀딩 믿고 먹는 오땡 양고기 ')
# ('wadiz', '푸드', '7차 앵콜 믿고 먹는 오땡 양고기')
#
# 데이 푸드
#
# 파스타
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '육즙 팡~ 한우가 씹히는! 진한 라구소스 볼로네제 라자냐 파스타')
# 루나
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# 바지락
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 국물
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '추운겨울에 생각나는 따듯한 국물 올바른다시팩으로 더 진하고 건강하게!')
# 미니미니
# 데이트
#
# 연구 뷰티
#
# 튀김
# 프로바이오틱스
# ('wadiz', '뷰티', '25년 연구 프로바이오틱스 전문가가 개발한 민감피부 전용 크림')
# 살의
# 닭다리
# 크런치
# 완벽
# 근육
#
# 정기 푸드
#
# 구독
# ('wadiz', '푸드', '겨울을 먹는다 3가지 향기를 맛보는 감귤스런 향기를 주간구독 먹찌요')
# ('wadiz', '푸드', '아이들을 위한 냉동간편식 정기구독서비스 아이라이쿡')
# 패닉
# 아홉
# 퍼포밍
# 서비스
# ('wadiz', '푸드', '진짜가 왔다! 가격 맛 서비스까지 다잡은 맛보지 못한 진짜 늙은 호박즙 ')
# 버튼
# 하노
# ('wadiz', '푸드', '1차앵콜 배부르게 먹어도 400Kcal? 5분OK 몬하노이 쌀국수와 분짜')
# ('wadiz', '푸드', '5분이면 하노이 맛집으로 소고기 쌀국수와 돼지 분짜 간편식')
#
# 충전 테크
#
# 무선
# ('wadiz', '테크', '5634 앵콜 가격은 서브 스펙은 메인듀얼 드라이버 무선이어폰')
# ('wadiz', '테크', '무선다리미 혁신 셔츠다림질에 까다로운 영국신사들이 열광한 모피리처드!')
# 시어스
# 충전기
# ('wadiz', '테크', '맥북2대 2.5시간 완충! 120WPD+70W올인원A 멀티 고속충전기')
# ('wadiz', '테크', '2만원대 아이템 하나로 공간을 바꾼다.감성까지 충전하는 무선충전기!')
# 뱅크
# ('wadiz', '테크', '해외 60억 EF DELTA 핸드폰부터 전기차까지 급속충전! 파워뱅크')
# ('wadiz', '테크', '팬톤 파워뱅크 15W 고속멀티무선충전+거치대+디자인을 모두 갖추다!')
# 급속
# ('wadiz', '테크', '해외 60억 EF DELTA 핸드폰부터 전기차까지 급속충전! 파워뱅크')
# 진공청소기
# ('wadiz', '테크', '파나소닉 와디즈 첫공개 진공청소+물걸레 3IN1 스마트 무선진공청소기')
#
# 무선 테크
#
# 충전기
# ('wadiz', '테크', '맥북2대 2.5시간 완충! 120WPD+70W올인원A 멀티 고속충전기')
# ('wadiz', '테크', '2만원대 아이템 하나로 공간을 바꾼다.감성까지 충전하는 무선충전기!')
# 뱅크
# ('wadiz', '테크', '해외 60억 EF DELTA 핸드폰부터 전기차까지 급속충전! 파워뱅크')
# ('wadiz', '테크', '팬톤 파워뱅크 15W 고속멀티무선충전+거치대+디자인을 모두 갖추다!')
# 듀얼
# ('wadiz', '테크', '5634 앵콜 가격은 서브 스펙은 메인듀얼 드라이버 무선이어폰')
# ('wadiz', '테크', '5만원대로 팬톤무선이어폰+듀얼충전패드? 그런데 그것이 실제 일어났습니다!')
# 충전
# ('wadiz', '테크', '5만원대로 팬톤무선이어폰+듀얼충전패드? 그런데 그것이 실제 일어났습니다!')
# 진공청소기
# ('wadiz', '테크', '파나소닉 와디즈 첫공개 진공청소+물걸레 3IN1 스마트 무선진공청소기')
# 드라이버
# ('wadiz', '테크', '5634 앵콜 가격은 서브 스펙은 메인듀얼 드라이버 무선이어폰')
# ('wadiz', '테크', '가격은 서브 스펙은 메인5백만명 인정한 듀얼 드라이버 무선이어폰')
# 고속
# ('wadiz', '테크', '나만의 스마트폰 영화관 디쉬 캡 그리고 고속무선충전 닷C')
# ('wadiz', '테크', '팬톤 파워뱅크 15W 고속멀티무선충전+거치대+디자인을 모두 갖추다!')
#
# 컬렉션 홈리빙
#
# 농부
# 감칠맛
# 애니메이션
# 직송
# 임명
# 경력
# 정산
#
# 검증 뷰티
#
# 갈바
# ('wadiz', '뷰티', '1.3억 앵콜 하루만에 수분140증가! 임상후기검증 갈바닉 마스크')
# ('wadiz', '뷰티', '오.늘.마.감 하루만에 수분140증가! 임상후기검증 갈바닉 마스크')
# 백신
# 어쩌
# 증가
# ('wadiz', '뷰티', '1.3억 앵콜 하루만에 수분140증가! 임상후기검증 갈바닉 마스크')
# ('wadiz', '뷰티', '오.늘.마.감 하루만에 수분140증가! 임상후기검증 갈바닉 마스크')
# 후기
# ('wadiz', '뷰티', '1.3억 앵콜 하루만에 수분140증가! 임상후기검증 갈바닉 마스크')
# ('wadiz', '뷰티', '누적1억신화후기로 검증된 신개념 여성청결제 이너샤인 냄새안녕!!')
# 폭주
#
# 변화 뷰티
#
# 해삼
# ('wadiz', '뷰티', '미스터리한 해삼으로 28일간 벌어질 놀라온 피부 변화 해삼노니앰플')
# 교사
# 팬데믹
# 토트
# 앰플
# ('wadiz', '뷰티', '4만원대 LED 디바이스이중기능성 유산균 앰플의 가성비 꿀조합!')
# ('wadiz', '뷰티', '1300개 한정 당신의 피부를 도화지처럼 미백+수분+피부활력 앰플')
# ('wadiz', '뷰티', '세상에 없기에 만들었다! 이거 하나면 끝! 진짜 앰플 맞아?')
# 쏙쏙
# ('wadiz', '뷰티', '5.0점앵콜펀딩천연 사해머드로 영양을 쑥쑥! 자석으로 노폐물을 쏙쏙!')
# 미래
#
# 비법 푸드
#
# 임원경제지
# ('tumblbug', '푸드', '조선 최대의 음식요리 백과사전 임원경제지 정조지')
# 남현
# ('wadiz', '푸드', '김치품평회 대상 34년 장인의 비법을 담은 내손내만 김장키트남현김치')
# ('wadiz', '푸드', '4.7점 앵콜김치품평회 대상 국민 김치와 비건이 만나다 남현김치')
# 뽀개기
# 카라멜
# ('wadiz', '푸드', '놀라지마세요!고급스러운 풍미 간장 카라멜')
# ('wadiz', '푸드', '1분만에 100배 맛있어진다? 풍미치트키 양파 카라멜라이징!!')
# ('tumblbug', '푸드', '수제 버터 카라멜이 들어간 다크 초콜릿 스틱')
# 유자
# ('wadiz', '푸드', '월간다과12월의 유자로 만든 한식 디저트 유자단지 그리고 유자정과')
# ('wadiz', '푸드', '향긋한 유자차를 건강하게 즐기는 방법! 단맛 칼로리 걱정 No!')
# ('wadiz', '푸드', ' 3748 앵콜 일주일 한정 유자로 80시간 숙성한 비법 연어')
# 백과사전
# ('tumblbug', '푸드', '조선 최대의 음식요리 백과사전 임원경제지 정조지')
# 투잡
#
# 고급 홈리빙
#
# 식기
# ('wadiz', '홈리빙', '가지고 싶었던 고급 원목 식기~! 우리집 식탁을 고급스럽게')
# 원목
# ('wadiz', '홈리빙', '가지고 싶었던 고급 원목 식기~! 우리집 식탁을 고급스럽게')
# 식탁
# ('wadiz', '홈리빙', '가지고 싶었던 고급 원목 식기~! 우리집 식탁을 고급스럽게')
# 키핑
# 호텔
# ('wadiz', '홈리빙', '고급향수야? 룸스프레이야? 전세계 고급호텔 향 3만원대 한병에 담다!')
# ('wadiz', '홈리빙', '여행 못 가도 괜찮아. 호텔느와르만 있으면 여기가 호텔이고 여행지!')
# 구멍
# ('wadiz', '홈리빙', '청바지를 수호하라 청바지 가랑이 구멍 해결사')
#
# 크리스마스 푸드
#
# 랩그
# 기념일
# 배송
# ('wadiz', '푸드', '크리스마스 리미티드 프리미엄 암소한우! 후기보시고 펀딩!이브날전에배송')
# 슬로
# ('wadiz', '푸드', '해슬로 얼리크리스마스 당신의 식탁위에 크리스마스의 기적이 펼쳐집니다')
# ('wadiz', '푸드', '슬로우 제주 슬로우 티 집에서 만나는 제주 차 한잔')
# 회식
# ('wadiz', '푸드', '16회 앵콜 인생참치회 크리스마스회식')
# ('wadiz', '푸드', '야근으로! 회식으로! 숙취로! 눈뜨기 힘든 아침도 난 괜찮아 오늘')
# 캐롤
# 고생
# ('wadiz', '푸드', '꿈꾸는고기 올 해 고생했다! 리얼 스테이크 파이 먹고 힘내자! ')
#
# 차량 테크
#
# 보냉컵홀더
# 방향
# 트라이던트
# 와이퍼
# 발상
# ('wadiz', '테크', '줌화상회의 유튜브 방송을 위한 무선마이크  발상 B3 ZOOMIC 줌익')
# 모빌리티
# ('wadiz', '테크', '2029달성 앵콜펀딩 무선충전과 스피커까지 담은 모빌리티 거치대')
# 고속
# ('wadiz', '테크', '나만의 스마트폰 영화관 디쉬 캡 그리고 고속무선충전 닷C')
# ('wadiz', '테크', '팬톤 파워뱅크 15W 고속멀티무선충전+거치대+디자인을 모두 갖추다!')
#
# 필수 푸드
#
# 유튜
# 목줄
# 작업시간
# 내열
# 퇴각
# 워킹
#
# 감귤 푸드
#
# 더덕
# ('wadiz', '푸드', '달콤가루차 앵콜 평점5! 달콤 쑥 가루와 감귤생강 가루 더덕 가루')
# 가루차
# ('wadiz', '푸드', '달콤가루차 앵콜 평점5! 달콤 쑥 가루와 감귤생강 가루 더덕 가루')
# 가루
# ('wadiz', '푸드', '밀가루가 없는데 맛있는 와플이 있다? 프로틴 와플 두둥 등장')
# ('wadiz', '푸드', '달콤가루차 앵콜 평점5! 달콤 쑥 가루와 감귤생강 가루 더덕 가루')
# 달콤
# ('wadiz', '푸드', '달콤가루차 앵콜 평점5! 달콤 쑥 가루와 감귤생강 가루 더덕 가루')
# ('wadiz', '푸드', '새콤달콤 오디로 만든 발사믹 식초! 뽕발사믹식초에 뽕당 빠져보세요!')
# ('wadiz', '푸드', '2차 앵콜 올해의 마지막을 새콤달콤하게 장식할 만감류의 여왕 레드향')
# 생강
# ('wadiz', '푸드', '달콤가루차 앵콜 평점5! 달콤 쑥 가루와 감귤생강 가루 더덕 가루')
# ('wadiz', '푸드', '나트륨절반!풍미는두배!내몸을지키는1mm의기적!100국내산생강소금!!')
# ('wadiz', '푸드', '마실거리 고민 이제 끝! 상큼하고 달달한 레몬생강차를 준비했어요')
# 첨가
# ('wadiz', '푸드', '4조 유산균이 첨가된 아이스크림이 있다고? 아이스크림은 그랬어야한다')
# ('wadiz', '푸드', '첨가물 부형제 NO! 비타면역젤리로 우리 아이 면역력 향상 프로젝트!')
#
# 할머니 푸드
#
# 손녀
# 선생님
# 하라
# 지옥
# 그때
# 스승
# 긴급
#
# 로컬 푸드
#
# 전라도
# ('wadiz', '푸드', '배추 총각 깍두기 백김치까지 맛있는 전라도김치가 왔다!')
# 청년
# ('wadiz', '푸드', '의성 청년농부가 직접 농사지은 꿀부사를 소개합니다.')
# ('wadiz', '푸드', '제주청년농부의 효돈감귤과 아이들')
# 냉동
# ('wadiz', '푸드', '로컬의 맛 동남아 냉동 도시락 전자레인지 단 5분 완성 ')
# ('wadiz', '푸드', '아이들을 위한 냉동간편식 정기구독서비스 아이라이쿡')
# 농부
# ('wadiz', '푸드', '당일도정산지직송 52년 경력 장인 농부의 감칠맛 나는 쌀 컬렉션!')
# ('wadiz', '푸드', '의성 청년농부가 직접 농사지은 꿀부사를 소개합니다.')
# ('wadiz', '푸드', '제주청년농부의 효돈감귤과 아이들')
# 도시락
# ('wadiz', '푸드', '로컬의 맛 동남아 냉동 도시락 전자레인지 단 5분 완성 ')
# 카이
# ('wadiz', '푸드', '카이스트 출신이 뭉쳐서 만든 남자를 위한 고농축 엑기스! 마카롱EX')
# 샐러드
# ('wadiz', '푸드', '샐러드 전용 국내산 발사믹 드레싱으로 간편하고 맛있게 먹자!')
# ('wadiz', '푸드', '전국 각 지역의 샐러드를 먹어보고 싶다면? 맛을 강조하는 로컬샐러드')
# ('wadiz', '푸드', '어렵고 복잡한 식단 관리는 그만! 내 영양 상태에 꼭! 맞춘 샐러드 식단')
#
# 호텔 홈리빙
#
# 숙박
# ('wadiz', '홈리빙', '225앵콜한국은 왜 구스이불이 비싸죠?호텔 숙박비로 매일 숙면을!')
# 느와르
# ('wadiz', '홈리빙', '여행 못 가도 괜찮아. 호텔느와르만 있으면 여기가 호텔이고 여행지!')
# 거리
# ('wadiz', '홈리빙', '한폭의 그림을 담요에 담았다! 통통튀는 감성 책거리냥 포근담요')
# 복합
# 세렌
# 홈파티
# 실내
# ('wadiz', '홈리빙', '스멜탄 탈취제가 탈취 디퓨저로! 향으로 덮지 않고 실내 악취 원천 제거')
#
# 다이어리 디자인
#
# 애뽈
# ('tumblbug', '디자인', '애뽈의 2021 숲소녀 다이어리달력')
# ('tumblbug', '디자인', '애뽈의 2020 숲소녀 다이어리달력')
# 캡처
# 파크
# ('tumblbug', '디자인', '모든 소망을 현실로 2020 루나파크 다이어리')
# ('tumblbug', '디자인', '모든 행운을 너에게 2019 루나파크 다이어리')
# 만년
# ('tumblbug', '디자인', '버려진 자투리 가죽에서 찾은 시간의 조각 만년달력 손거울')
# 여섯
# ('tumblbug', '디자인', '오늘도 힘들었을 당신을 위한 샤인플라워 여섯가지 꽃말들')
# ('tumblbug', '디자인', '여섯달의 기록 mon journal 다이어리')
# ('tumblbug', '디자인', '열여섯 딸과 함께 만든 만년 다이어리')
# 러브스토리
# 물고기
# ('tumblbug', '디자인', '2021 계절을 알려주는 물고기 계향어')
#
# 만족 푸드
#
# 숨숨
# 충분
# 타워
# 트윈
# 평균
# ('tumblbug', '푸드', '평균 당류 1.42g 맛과 영양 듬뿍 저당 그래놀라의 탄생')
# 안성맞춤
# 코너
#
# 키트 푸드
# 처방
# 채식
# ('wadiz', '푸드', '개취존중육식파 채식파 드루와~ 커스터마이징 펜네파스타 먹기좋은연말이네')
# 검사
# 수질검사
# 포포
#
# 이야기 푸드
#
# 요괴
# 일간
# ('wadiz', '푸드', '한정수량 7일간 랍스터x연어파티근사하지만 간편한 크리스마스 홈파티')
# 뱅글
# 헌법
# 물음
# 최후
#
# 향수 홈리빙
#
# 압생트
# 향기
# ('wadiz', '홈리빙', '인센스스틱홀더향기를 담는 케이스 _ 바르데로 더케이스2')
# 르파써
# 퍼퓸
# ('wadiz', '홈리빙', '소피스런던 드레스퍼퓸 죄송합니다. 이건 향수가 아닙니다.')
# ('wadiz', '홈리빙', '8천원대 오드퍼퓸급 국민섬유향수 향수메이커 네이처그린')
# 바닐라
# 리운스
# 무화과
#
# 요리 푸드
#
# 동결
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 레테
# 수가
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 바지락
# ('wadiz', '푸드', '당장 밥말아 먹고 싶은 파스타가 왔다! 데이루나 바지락 국물 파스타')
# ('wadiz', '푸드', '세상에 이렇게 간단할 수가!? 만능 요리치트키 동결건조 바지락!!')
# 강화도
# ('wadiz', '푸드', '강화도 청소년들이 전하는 섬의 이야기가 담긴 고구마를 요리로 즐겨보세요!')
# 요빠
# ('wadiz', '푸드', '요리하는 아빠 요빠에서 준비한 정성 가득한 집밥 밀키트')
# 루스
# ('tumblbug', '푸드', '그랑 라루스 요리백과 그랑 라루스 와인백과')
#
# 요리 홈리빙
#
# 동결
# 레테
# 수가
# ('wadiz', '홈리빙', '우리가 알던 큐브맞아? UNIST교수가 4년만에 개발한 큐브의 신세계!')
# ('wadiz', '홈리빙', '소피스런던 드레스퍼퓸 죄송합니다. 이건 향수가 아닙니다.')
# 바지락
# 강화도
# 요빠
# 루스
#
# 배송 푸드
#
# 러프
# 랩그
# 고생
# ('wadiz', '푸드', '꿈꾸는고기 올 해 고생했다! 리얼 스테이크 파이 먹고 힘내자! ')
# 프로포즈
# 신선
# ('wadiz', '푸드', '매주 신선배송 1등급 원유로 만든 여성을 위한 프로틴풀무원 레깅스밀')
# 기념일
# 크리스마스
#
# 모공 뷰티
#
# 사수
# ('wadiz', '뷰티', '펀딩만 해도 본품 선물모공속에 미생물을 채우세요 모공 사수 세럼')
# 피지
# ('wadiz', '뷰티', '리뉴얼푸딩수딩2.0 모공 피지 정돈까지 한번에 빠른 진정케어')
# ('wadiz', '뷰티', '임상 피지 노폐물 OUT! 비타민 IN! 맑은 피부 바탕 파우더팩')
# 노폐물
# ('wadiz', '뷰티', '앵콜 유분모공관리? 피노누아 버블로 모공 속 노폐물까지 관리하세요')
# ('wadiz', '뷰티', '임상 피지 노폐물 OUT! 비타민 IN! 맑은 피부 바탕 파우더팩')
# ('wadiz', '뷰티', '5.0점앵콜펀딩천연 사해머드로 영양을 쑥쑥! 자석으로 노폐물을 쏙쏙!')
# 각질
# ('wadiz', '뷰티', '후기 과장이라 생각했는데 하루만에 효과가 나타났어요! 발각질 끝장템')
# ('tumblbug', '뷰티', '세계 최초 특허받은 글라스로 만든 흡입형 전동 발각질제거기')
# 미생물
# ('wadiz', '뷰티', '펀딩만 해도 본품 선물모공속에 미생물을 채우세요 모공 사수 세럼')
# 클렌
# ('wadiz', '뷰티', '클렌징폼? 이젠 페이스 클렌저! 진짜 향료FREE! 촉촉 진정 세안하세요')
# ('wadiz', '뷰티', '클렌징 보습 및 복합기능성을 한번에! 더팩트 에스에프엔 에이틴 스킨토너')
# ('wadiz', '뷰티', '클보 이것저것 클렌저 유목생활 끝. 우리집 폼클렌저 부스팅업 클보')
#
# 모공 뷰티
#
# 사수
# ('wadiz', '뷰티', '펀딩만 해도 본품 선물모공속에 미생물을 채우세요 모공 사수 세럼')
# 피지
# ('wadiz', '뷰티', '리뉴얼푸딩수딩2.0 모공 피지 정돈까지 한번에 빠른 진정케어')
# ('wadiz', '뷰티', '임상 피지 노폐물 OUT! 비타민 IN! 맑은 피부 바탕 파우더팩')
# 노폐물
# ('wadiz', '뷰티', '앵콜 유분모공관리? 피노누아 버블로 모공 속 노폐물까지 관리하세요')
# ('wadiz', '뷰티', '임상 피지 노폐물 OUT! 비타민 IN! 맑은 피부 바탕 파우더팩')
# ('wadiz', '뷰티', '5.0점앵콜펀딩천연 사해머드로 영양을 쑥쑥! 자석으로 노폐물을 쏙쏙!')
# 각질
# ('wadiz', '뷰티', '후기 과장이라 생각했는데 하루만에 효과가 나타났어요! 발각질 끝장템')
# ('tumblbug', '뷰티', '세계 최초 특허받은 글라스로 만든 흡입형 전동 발각질제거기')
# 미생물
# ('wadiz', '뷰티', '펀딩만 해도 본품 선물모공속에 미생물을 채우세요 모공 사수 세럼')
# 클렌
# ('wadiz', '뷰티', '클렌징폼? 이젠 페이스 클렌저! 진짜 향료FREE! 촉촉 진정 세안하세요')
# ('wadiz', '뷰티', '클렌징 보습 및 복합기능성을 한번에! 더팩트 에스에프엔 에이틴 스킨토너')
# ('wadiz', '뷰티', '클보 이것저것 클렌저 유목생활 끝. 우리집 폼클렌저 부스팅업 클보')
#
# 전통 푸드
#
# 소반
# 현대
# ('wadiz', '푸드', '현대인 필수템릴렉싱 맞춤형 프리미엄 블렌딩티 2종 chawa ')
# 호담
# 참기름
# ('wadiz', '푸드', '참치 참기름 그만! 설 선물은 픽찌 버섯 장아찌로 해결하세요!')
# ('wadiz', '푸드', '문경의 50년 전통 찐 참기름과 들기름')
# ('wadiz', '푸드', '바로 볶아서 저온압착으로 짠 참기름 들기름 40년전통 압구정 현대방앗간')
# 냉면
# ('wadiz', '푸드', '반평생 걷던 외길 47년 전통 냉면 장인이 선보이는 진짜 메밀냉면')
#
# 전세계 홈리빙
#
# 오토
# 독자
# 돈버는법
# 유튜브
# 무려
# ('wadiz', '홈리빙', '무려 16535 앵콜 다시 돌아온 주방의 로망 무쇠팬과 웍팬')
# 매틱
#
# 집콕 푸드
#
# 직소
# 문화생활
# 해금
# 색동
# 악기
# 호스
# ('wadiz', '푸드', '제주 과일의 다크호스 제대로 숙성한 초달콤 레드키위')
#
# 비타민 푸드
#
# 항산화
# ('wadiz', '푸드', '첨가물없는 자연원료 항산화와 면역을 동시에! 포뉴 그린 프로폴리스')
# 사표
# 잔틴
# 프로폴리스
# ('wadiz', '푸드', '첨가물없는 자연원료 항산화와 면역을 동시에! 포뉴 그린 프로폴리스')
# 히알루론산
# ('wadiz', '푸드', '2차앵콜콜라겐+히비스커스+히알루론산+엘라스틴 1포에담은 석류콜라겐젤리')
# 유효
# 노폐물
#
# 비타민 뷰티
#
# 항산화
# ('wadiz', '뷰티', '피부전달연구소가 만든 에센스피부심층까지 딜리버리 항산화 원정대 모집')
# ('wadiz', '뷰티', '올로아36 푸코잔틴 항산화 앰플 바다의 에너지를 담은 항산화 앰플')
# 사표
# ('wadiz', '뷰티', '사표 던지고 18개월 동안 개발한 진짜 어성초 히알루론산 에센스')
# 잔틴
# ('wadiz', '뷰티', '올로아36 푸코잔틴 항산화 앰플 바다의 에너지를 담은 항산화 앰플')
# ('wadiz', '뷰티', '비타민C 6천배 항산화 제왕 아스타잔틴과 미스트의 만남! 꿀 피부 만들기')
# 프로폴리스
# ('wadiz', '뷰티', '브라질 아마존의 레드프로폴리스 피부진정 효과의 정점 BBH 앰플')
# 히알루론산
# ('wadiz', '뷰티', '사표 던지고 18개월 동안 개발한 진짜 어성초 히알루론산 에센스')
# ('wadiz', '뷰티', '비자극임상리얼히알루론산성분 피부가 좋아보이는건 기분탓?아니 수분탓')
# 유효
# ('wadiz', '뷰티', '줄기세포배양액추출물 293850ppm에 다른 유효성분까지 가득한 크림!')
# ('wadiz', '뷰티', '잡티는 가려도 결은 가려지지 않아요 91유효성분 그대로 결콜라겐크림')
# 노폐물
# ('wadiz', '뷰티', '앵콜 유분모공관리? 피노누아 버블로 모공 속 노폐물까지 관리하세요')
# ('wadiz', '뷰티', '임상 피지 노폐물 OUT! 비타민 IN! 맑은 피부 바탕 파우더팩')
# ('wadiz', '뷰티', '5.0점앵콜펀딩천연 사해머드로 영양을 쑥쑥! 자석으로 노폐물을 쏙쏙!')
#
# 전문가 홈리빙
#
# 한국인
# 자주
# 왕초보
# 특허성
# 자시
# 러그
# ('wadiz', '홈리빙', '10753 앵콜 쏟아도 괜찮아! 32년 장인의 감성 방수 러그')
# ('wadiz', '홈리빙', '안전한 프리미엄 코튼 러그의 기준을 제시합니다')
# ('wadiz', '홈리빙', '이제 쏟아도 괜찮아! 32년 카펫 전문가가 만드는 감성 방수 러그 ')
# 고소
#
# 화장품 뷰티
#
# 체험판
# ('wadiz', '뷰티', '최대 혜택서포터님들을 위한 EGFFGF화장품 체험판4차 ')
# ('wadiz', '뷰티', '마진을 포기한 서포터님들을 위한 EGFFGF화장품 체험판 3차')
# ('wadiz', '뷰티', '마진을 포기한 서포터님들을 위한 EGFFGF화장품 체험판 2차')
# 나노입자
# ('tumblbug', '뷰티', '투명한 피부의 비결 황칠 나노입자 화장품 엑소드랍')
# ('tumblbug', '뷰티', '환한 피부의 비결 식물 나노입자 화장품 엑소드랍')
# 엑소
# ('tumblbug', '뷰티', '투명한 피부의 비결 황칠 나노입자 화장품 엑소드랍')
# ('tumblbug', '뷰티', '환한 피부의 비결 식물 나노입자 화장품 엑소드랍')
# 포렌
# 도화지
# ('wadiz', '뷰티', '1300개 한정 당신의 피부를 도화지처럼 미백+수분+피부활력 앰플')
# 미백
# ('wadiz', '뷰티', '에디터의 선택광고 에디터들의 리얼픽! 밀드플레르 미백 탄력 비건 크림')
# ('wadiz', '뷰티', '평점4.9앵콜9차 올인원 + 미백기능 강화 아임젠틀 올인원 에센스')
# 비결
# ('tumblbug', '뷰티', '투명한 피부의 비결 황칠 나노입자 화장품 엑소드랍')
# ('tumblbug', '뷰티', '환한 피부의 비결 식물 나노입자 화장품 엑소드랍')
#
# 냄새 홈리빙
#
# 알콜
# ('wadiz', '홈리빙', '항균탈취퍼프머리아픈 알콜냄새는 그만! 뿌리지말고 톡톡 제로나노팩')
# 마밍스
# 분비물
# 리운스
# 헤파
# 퍼프
# ('wadiz', '홈리빙', '항균탈취퍼프머리아픈 알콜냄새는 그만! 뿌리지말고 톡톡 제로나노팩')
# 관능
#
# 디지털 디자인
#
# 캡처
# 아날로그
# ('wadiz', '디자인', '앵콜 아날로그적인 감성과 유니크함을 넣으세요.바르데로 더 케이스')
# ('wadiz', '디자인', '아날로그와 디지털을 아우르는 단하나의 만능 스탠드 가봇')
# ('tumblbug', '디자인', '나의 아날로그 기록의 안식처 keep paper')
# 퍼팅
# 연습기
# 급상승
# 페이스북
#
# 시작 홈리빙
#
# 금물
# 핵심
# 기구
# 자리
# ('wadiz', '홈리빙', '패키지앵콜네오아이더 꿀조합 패키지로 가볍고 따뜻한 신축년 잠자리준비끝')
# 체지방
# 사과쥬스
# 나인
#
# 추천 홈리빙
#
# 홈트족
# 카밋
# 신용
# 체크카드
# 설계서
# 인문학
# 증명
#
# 젤리 푸드
#
# 첨가
# ('wadiz', '푸드', '4조 유산균이 첨가된 아이스크림이 있다고? 아이스크림은 그랬어야한다')
# ('wadiz', '푸드', '첨가물 부형제 NO! 비타면역젤리로 우리 아이 면역력 향상 프로젝트!')
# 프리바이오틱스
# ('wadiz', '푸드', '매일밤 꿀잠해~ 유기농 타트체리 프리바이오틱스')
# ('wadiz', '푸드', '인생젤리각 과즙이 팡팡~ 프리바이오틱스 젤리인데 맛있기까지?')
# 비타
# ('wadiz', '푸드', '집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리')
# 면역
# ('wadiz', '푸드', '몸과 마음의 건강균형을 위해 스트레스 완화와 정상적인 면역기능을 한번에')
# ('wadiz', '푸드', '하루 513원! 올인원 면역캡슐로 면역력 챙기세요')
# ('wadiz', '푸드', '첨가물 부형제 NO! 비타면역젤리로 우리 아이 면역력 향상 프로젝트!')
# 설탕
# ('wadiz', '푸드', '독일에서 온 설탕인듯 설탕아닌 건강한 대체 설탕 0kcal슈카라이트')
# ('wadiz', '푸드', '집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리')
# ('wadiz', '푸드', '설탕 0g 죄책감 없이 마구 퍼먹는 티라미수 크리스마스 시즌선물!')
# 약사
# ('wadiz', '푸드', '1끼 966원 약사가 만든 80kcal 포만 가득 쌀단백 한끼 프로틴')
# ('wadiz', '푸드', '약사가 만든 아침을 깨우는 편리한 참당귀 액상차 필미업플러스')
# ('wadiz', '푸드', '식후에 먹으면 좋은 한약사와 공동개발한 평위환')
# 엘라스
# ('wadiz', '푸드', '2차앵콜콜라겐+히비스커스+히알루론산+엘라스틴 1포에담은 석류콜라겐젤리')
# ('wadiz', '푸드', '콜라겐 엘라스틴 히알루론산 3가지 모두 담은 프리미엄 액상콜라겐')
#
# 설탕 푸드
#
# 슈카
# ('wadiz', '푸드', '독일에서 온 설탕인듯 설탕아닌 건강한 대체 설탕 0kcal슈카라이트')
# 대체
# ('wadiz', '푸드', '독일에서 온 설탕인듯 설탕아닌 건강한 대체 설탕 0kcal슈카라이트')
# 탄산음료
# ('wadiz', '푸드', '1억앵콜 설탕쏙뺀 8kcal 탄산음료 리얼 복숭아 피치클링!')
# ('wadiz', '푸드', '2억4천앵콜 한라봉으로 돌아온 설탕쏙뺀 8kcal 탄산음료!')
# 상큼
# ('wadiz', '푸드', '마실거리 고민 이제 끝! 상큼하고 달달한 레몬생강차를 준비했어요')
# ('wadiz', '푸드', '집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리')
# 청포도
# ('wadiz', '푸드', '나의 아름다움을 1포에 담았다! 청포도와 저분자피쉬콜라겐을 스틱 하나에!')
# ('tumblbug', '푸드', '달콤 상큼한 청포도 맛을 지닌 콜드브루 파나마 파밀라')
# 젤리
# ('wadiz', '푸드', '집콕필수템 NO설탕 NO물엿 상큼감귤 프리바이오틱 비타민 젤리')
# ('wadiz', '푸드', '첨가물 부형제 NO! 비타면역젤리로 우리 아이 면역력 향상 프로젝트!')
# ('wadiz', '푸드', '2차앵콜콜라겐+히비스커스+히알루론산+엘라스틴 1포에담은 석류콜라겐젤리')
# 홍차
# ('wadiz', '푸드', '샵소이 두유 100 국산콩으로 만든 프리미엄 얼그레이 홍차 두유')
# ('wadiz', '푸드', '국내산 프리미엄 홍차와 삶의 여유를 찾다 마시다클라시블랙티')
# ('wadiz', '푸드', '홍차브루커피 앵콜 누적 1억4천! 커피에 대체 무슨짓을 하신 거에요?')
#
# 도마 홈리빙
#
# 숨결
# ('wadiz', '홈리빙', '엔드그레인도마 나무숨결 나이테 도마 데코레이션 도마')
# 원목
# ('wadiz', '홈리빙', '가지고 싶었던 고급 원목 식기~! 우리집 식탁을 고급스럽게')
# 데코
# ('wadiz', '홈리빙', '엔드그레인도마 나무숨결 나이테 도마 데코레이션 도마')
# 달인
# ('wadiz', '홈리빙', '국민 캄포도마 도마의 달인이 만든 2만 원 초반의 통원목 캄포 도마')
# 민국
# 베젤
# 플레이
# ('wadiz', '홈리빙', '홈카페에서 홈스타일링 인테리어까지 대리석 화병 플레이트')
# ('wadiz', '홈리빙', '일회용 접시는 이제 그만! 가볍고 안전한 리유저블 실리콘 플레이트')
#
# 피부 뷰티
#
# 도화지
# ('wadiz', '뷰티', '1300개 한정 당신의 피부를 도화지처럼 미백+수분+피부활력 앰플')
# 가려움
# ('wadiz', '뷰티', '수분크림임상 효과 입증피부건조가려움! 참지 말고 BM크림 바르세요')
# ('wadiz', '뷰티', '진정 마름 가려움 없는 피부 by 청정 제주 허벌케어 ')
# 앰플
# ('wadiz', '뷰티', '4만원대 LED 디바이스이중기능성 유산균 앰플의 가성비 꿀조합!')
# ('wadiz', '뷰티', '1300개 한정 당신의 피부를 도화지처럼 미백+수분+피부활력 앰플')
# ('wadiz', '뷰티', '세상에 없기에 만들었다! 이거 하나면 끝! 진짜 앰플 맞아?')
# 진정
# ('wadiz', '뷰티', '앵콜펀딩 대서양 보습원료로 만든 해초시트! 저자극 보습진정 마스크팩')
# ('wadiz', '뷰티', '클렌징폼? 이젠 페이스 클렌저! 진짜 향료FREE! 촉촉 진정 세안하세요')
# ('wadiz', '뷰티', '모공과 피부진정?이거 하나면 끝!!! 구아이아줄렌+센텔라의 환상궁합')
# 알란
# ('wadiz', '뷰티', '평점 4.9 앵콜 민감피부 고민종결 붉은기까지 알란토시카가 뭔데?')
# ('wadiz', '뷰티', '1000분 지속 민감이들도 하루 종일 만족할 수 있다고? 알란토시카')
# 민감
# ('wadiz', '뷰티', '평점 4.9 앵콜 민감피부 고민종결 붉은기까지 알란토시카가 뭔데?')
# ('wadiz', '뷰티', '민감 피부 고민 끝! 수분 진정으로 채운 피부 방어력 비건시카 크림')
# 토시
# ('wadiz', '뷰티', '평점 4.9 앵콜 민감피부 고민종결 붉은기까지 알란토시카가 뭔데?')
# ('wadiz', '뷰티', '1000분 지속 민감이들도 하루 종일 만족할 수 있다고? 알란토시카')
#
# 음식 푸드
#
# 장어
# ('wadiz', '푸드', '뻔한 음식 말고 간편한 장어로! 세상 맛있는 꿀장어 홈키트')
# ('wadiz', '푸드', '역대급 사이즈 장어명인의 맛을 그대로 담은 3분 구찌구구 민물장어')
# ('wadiz', '푸드', '3차 앵콜 기력 보충 영양 가득 국내산 민물장어')
# 한식
# ('wadiz', '푸드', '월간다과12월의 유자로 만든 한식 디저트 유자단지 그리고 유자정과')
# 임원경제지
# ('tumblbug', '푸드', '조선 최대의 음식요리 백과사전 임원경제지 정조지')
# 번은
# 안주
# ('wadiz', '푸드', '홈술안주 쥐포..먹고쥐포..구워..먹고쥐포...정말...먹고쥐포')
# ('wadiz', '푸드', '알콜러버 3차앵콜 힙한 크리스마스를 책임질 알코올티키트+안주박스')
# 두부
# ('wadiz', '푸드', '업글앵콜과자끊기힘들죠?갈아타세요!덜단덜짠 슴슴한 두부과자두부43')
# ('wadiz', '푸드', '북한국민음식 건강한 곤드레 두부밥과 이북식 만능 양념장')
# ('wadiz', '푸드', '국산콩두부가 55들어간 수제 비건과자 모르는 사람있나? 탕! 또 있나?')
# 분식
# ('wadiz', '푸드', '2020 올해의 떡볶이! 남산분식 곱창 떡볶이 + 갈릭 볶음밥')
#
# 제주 푸드
#
# 풋귤
# ('wadiz', '푸드', '찬바람 불 때 건강 생각 간편한 제주 풋귤 한 알! 제주 풋귤 단지차')
# 한라산
# 슬로우
# ('wadiz', '푸드', '슬로우 제주 슬로우 티 집에서 만나는 제주 차 한잔')
# 황금향
# ('wadiz', '푸드', '리얼 황금향뱅쇼 한겨울엔 제주 제철 생과일로 끓인 수제뱅쇼')
# ('wadiz', '푸드', '9차 앵콜2020년 마지막 순간을 달콤한 황금향과 함께 보내세요!')
# ('wadiz', '푸드', '8차 앵콜12월 황금기에 수확한 과즙 팡팡 베니 마돈나 황금향!')
# 유리컵
#
# 거치 테크
#
# 충전기
# ('wadiz', '테크', '맥북2대 2.5시간 완충! 120WPD+70W올인원A 멀티 고속충전기')
# ('wadiz', '테크', '2만원대 아이템 하나로 공간을 바꾼다.감성까지 충전하는 무선충전기!')
# 태블릿
# ('wadiz', '테크', '글로벌11억펀딩MOFT 노트북태블릿 파우치와 거치대를 하나로!')
# 드라이기
# ('wadiz', '테크', '무선드라이기에 새로운 가치를 더하다 _ 노마드')
# 스마트폰
# ('wadiz', '테크', '평점 4.5앵콜 1초컷 가죽 스마트폰 스탠드로 폰을 업그레이드 하세요')
# 모빌리티
# ('wadiz', '테크', '2029달성 앵콜펀딩 무선충전과 스피커까지 담은 모빌리티 거치대')
# 뱅크
# ('wadiz', '테크', '해외 60억 EF DELTA 핸드폰부터 전기차까지 급속충전! 파워뱅크')
# ('wadiz', '테크', '팬톤 파워뱅크 15W 고속멀티무선충전+거치대+디자인을 모두 갖추다!')
# 휴대폰
# ('wadiz', '테크', '걸리버거치대스마트폰과 테블릿을 같이 쓸수 있는 차량용 휴대폰 거치대')
#
# 노하우 뷰티
#
# 미드
# 실전
# 베이비
# ('wadiz', '뷰티', '탄력이 필요해? 전문 클리닉 노하우가 그대로 담긴 베이비콜라겐 앰플!')
# 쇼핑몰
# 꿀팁
# 수익
# 상세
#
# 295
